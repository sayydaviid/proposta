# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Número de sucessos desejados
success_target = 3  # Número desejado de sucessos

# Inicializa contadores
success_count = 0
attempt_count = 0

# Loop para rodar a simulação até o número desejado de sucessos
while success_count < success_target:
    attempt_count += 1
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "script.py", str(attempt_count)],
            capture_output=True,
            text=True,
            check=True
        )

        # Filtra a saída para tentar capturar apenas o JSON
        output = result.stdout.strip()

        # Exibe a inicialização das variáveis
        print(f"Tentativa {attempt_count}")
        print("Saída obtida: Hosts inicializados")
        print("Canais inicializados")
        print("Pares EPRs adicionados")

        # Filtra a parte do JSON
        json_str = ""
        try:
            # Encontra o JSON na saída
            start_idx = output.index('{')
            end_idx = output.rindex('}') + 1
            json_str = output[start_idx:end_idx]
        except ValueError:
            print(f"Tentativa {attempt_count} - Saída não contém JSON válido: {output}")
            continue
        
        # Verifica se a saída é um JSON válido
        try:
            simulation_result = json.loads(json_str)
            # Exibe o JSON com formatação bonita
            print(json.dumps(simulation_result, indent=4))
        except json.JSONDecodeError:
            print(f"Tentativa {attempt_count} - Erro ao processar JSON: {output}")
            continue
        
        # Verifica o sucesso da simulação
        if simulation_result.get("success", False):
            success_count += 1
            print(f"Simulação {attempt_count} bem-sucedida! (Sucessos: {success_count})")
        
        # Verifica se o número de sucessos desejado foi alcançado
        if success_count >= success_target:
            print(f"Alcançado o número de sucessos desejados ({success_target}). Finalizando simulações.")
            break  # Encerra o loop quando o número de sucessos for atingido

    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt_count}: {e}")
        continue

# Processa o arquivo CSV para coletar as métricas
try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Erro na execução da simulação 1: Command '['python', 'script.py', '1']' returned non-zero exit status 1.
# Erro na execução da simulação 2: Command '['python', 'script.py', '2']' returned non-zero exit status 1.
# Tentativa 3
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 4: Command '['python', 'script.py', '4']' returned non-zero exit status 1.
# Erro na execução da simulação 5: Command '['python', 'script.py', '5']' returned non-zero exit status 1.
# Tentativa 6
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 7: Command '['python', 'script.py', '7']' returned non-zero exit status 1.
# Erro na execução da simulação 8: Command '['python', 'script.py', '8']' returned non-zero exit status 1.
# Erro na execução da simulação 9: Command '['python', 'script.py', '9']' returned non-zero exit status 1.
# Erro na execução da simulação 10: Command '['python', 'script.py', '10']' returned non-zero exit status 1.
# Erro na execução da simulação 11: Command '['python', 'script.py', '11']' returned non-zero exit status 1.
# Tentativa 12
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 13: Command '['python', 'script.py', '13']' returned non-zero exit status 1.
# Erro na execução da simulação 14: Command '['python', 'script.py', '14']' returned non-zero exit status 1.
# Erro na execução da simulação 15: Command '['python', 'script.py', '15']' returned non-zero exit status 1.
# Erro na execução da simulação 16: Command '['python', 'script.py', '16']' returned non-zero exit status 1.
# Erro na execução da simulação 17: Command '['python', 'script.py', '17']' returned non-zero exit status 1.
# Erro na execução da simulação 18: Command '['python', 'script.py', '18']' returned non-zero exit status 1.
# Erro na execução da simulação 19: Command '['python', 'script.py', '19']' returned non-zero exit status 1.
# Erro na execução da simulação 20: Command '['python', 'script.py', '20']' returned non-zero exit status 1.
# Tentativa 21
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 22: Command '['python', 'script.py', '22']' returned non-zero exit status 1.
# Erro na execução da simulação 23: Command '['python', 'script.py', '23']' returned non-zero exit status 1.
# Erro na execução da simulação 24: Command '['python', 'script.py', '24']' returned non-zero exit status 1.
# Erro na execução da simulação 25: Command '['python', 'script.py', '25']' returned non-zero exit status 1.
# Erro na execução da simulação 26: Command '['python', 'script.py', '26']' returned non-zero exit status 1.
# Erro na execução da simulação 27: Command '['python', 'script.py', '27']' returned non-zero exit status 1.
# Tentativa 28
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 29: Command '['python', 'script.py', '29']' returned non-zero exit status 1.
# Erro na execução da simulação 30: Command '['python', 'script.py', '30']' returned non-zero exit status 1.
# Erro na execução da simulação 31: Command '['python', 'script.py', '31']' returned non-zero exit status 1.
# Tentativa 32
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 32,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 33: Command '['python', 'script.py', '33']' returned non-zero exit status 1.
# Erro na execução da simulação 34: Command '['python', 'script.py', '34']' returned non-zero exit status 1.
# Erro na execução da simulação 35: Command '['python', 'script.py', '35']' returned non-zero exit status 1.
# Tentativa 36
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 37: Command '['python', 'script.py', '37']' returned non-zero exit status 1.
# Erro na execução da simulação 38: Command '['python', 'script.py', '38']' returned non-zero exit status 1.
# Tentativa 39
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 40: Command '['python', 'script.py', '40']' returned non-zero exit status 1.
# Erro na execução da simulação 41: Command '['python', 'script.py', '41']' returned non-zero exit status 1.
# Erro na execução da simulação 42: Command '['python', 'script.py', '42']' returned non-zero exit status 1.
# Erro na execução da simulação 43: Command '['python', 'script.py', '43']' returned non-zero exit status 1.
# Tentativa 44
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 45: Command '['python', 'script.py', '45']' returned non-zero exit status 1.
# Erro na execução da simulação 46: Command '['python', 'script.py', '46']' returned non-zero exit status 1.
# Tentativa 47
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Tentativa 48
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 49: Command '['python', 'script.py', '49']' returned non-zero exit status 1.
# Erro na execução da simulação 50: Command '['python', 'script.py', '50']' returned non-zero exit status 1.
# Tentativa 51
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 52: Command '['python', 'script.py', '52']' returned non-zero exit status 1.
# Erro na execução da simulação 53: Command '['python', 'script.py', '53']' returned non-zero exit status 1.
# Erro na execução da simulação 54: Command '['python', 'script.py', '54']' returned non-zero exit status 1.
# Erro na execução da simulação 55: Command '['python', 'script.py', '55']' returned non-zero exit status 1.
# Erro na execução da simulação 56: Command '['python', 'script.py', '56']' returned non-zero exit status 1.
# Erro na execução da simulação 57: Command '['python', 'script.py', '57']' returned non-zero exit status 1.
# Erro na execução da simulação 58: Command '['python', 'script.py', '58']' returned non-zero exit status 1.
# Erro na execução da simulação 59: Command '['python', 'script.py', '59']' returned non-zero exit status 1.
# Tentativa 60
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Tentativa 61
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 62: Command '['python', 'script.py', '62']' returned non-zero exit status 1.
# Erro na execução da simulação 63: Command '['python', 'script.py', '63']' returned non-zero exit status 1.
# Erro na execução da simulação 64: Command '['python', 'script.py', '64']' returned non-zero exit status 1.
# Erro na execução da simulação 65: Command '['python', 'script.py', '65']' returned non-zero exit status 1.
# Tentativa 66
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 67: Command '['python', 'script.py', '67']' returned non-zero exit status 1.
# Tentativa 68
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 69: Command '['python', 'script.py', '69']' returned non-zero exit status 1.
# Erro na execução da simulação 70: Command '['python', 'script.py', '70']' returned non-zero exit status 1.
# Erro na execução da simulação 71: Command '['python', 'script.py', '71']' returned non-zero exit status 1.
# Erro na execução da simulação 72: Command '['python', 'script.py', '72']' returned non-zero exit status 1.
# Tentativa 73
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 74: Command '['python', 'script.py', '74']' returned non-zero exit status 1.
# Erro na execução da simulação 75: Command '['python', 'script.py', '75']' returned non-zero exit status 1.
# Tentativa 76
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 77: Command '['python', 'script.py', '77']' returned non-zero exit status 1.
# Tentativa 78
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 79: Command '['python', 'script.py', '79']' returned non-zero exit status 1.
# Tentativa 80
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 81: Command '['python', 'script.py', '81']' returned non-zero exit status 1.
# Tentativa 82
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 83: Command '['python', 'script.py', '83']' returned non-zero exit status 1.
# Erro na execução da simulação 84: Command '['python', 'script.py', '84']' returned non-zero exit status 1.
# Tentativa 85
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 86
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 87
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 88: Command '['python', 'script.py', '88']' returned non-zero exit status 1.
# Erro na execução da simulação 89: Command '['python', 'script.py', '89']' returned non-zero exit status 1.
# Erro na execução da simulação 90: Command '['python', 'script.py', '90']' returned non-zero exit status 1.
# Erro na execução da simulação 91: Command '['python', 'script.py', '91']' returned non-zero exit status 1.
# Erro na execução da simulação 92: Command '['python', 'script.py', '92']' returned non-zero exit status 1.
# Tentativa 93
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 94: Command '['python', 'script.py', '94']' returned non-zero exit status 1.
# Tentativa 95
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 95,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 96: Command '['python', 'script.py', '96']' returned non-zero exit status 1.
# Erro na execução da simulação 97: Command '['python', 'script.py', '97']' returned non-zero exit status 1.
# Erro na execução da simulação 98: Command '['python', 'script.py', '98']' returned non-zero exit status 1.
# Erro na execução da simulação 99: Command '['python', 'script.py', '99']' returned non-zero exit status 1.
# Erro na execução da simulação 100: Command '['python', 'script.py', '100']' returned non-zero exit status 1.
# Tentativa 101
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 101,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 102: Command '['python', 'script.py', '102']' returned non-zero exit status 1.
# Erro na execução da simulação 103: Command '['python', 'script.py', '103']' returned non-zero exit status 1.
# Tentativa 104
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 104,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 105: Command '['python', 'script.py', '105']' returned non-zero exit status 1.
# Erro na execução da simulação 106: Command '['python', 'script.py', '106']' returned non-zero exit status 1.
# Tentativa 107
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 107,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 108: Command '['python', 'script.py', '108']' returned non-zero exit status 1.
# Erro na execução da simulação 109: Command '['python', 'script.py', '109']' returned non-zero exit status 1.
# Erro na execução da simulação 110: Command '['python', 'script.py', '110']' returned non-zero exit status 1.
# Erro na execução da simulação 111: Command '['python', 'script.py', '111']' returned non-zero exit status 1.
# Erro na execução da simulação 112: Command '['python', 'script.py', '112']' returned non-zero exit status 1.
# Tentativa 113
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 113,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 114: Command '['python', 'script.py', '114']' returned non-zero exit status 1.
# Tentativa 115
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 115,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 116: Command '['python', 'script.py', '116']' returned non-zero exit status 1.
# Erro na execução da simulação 117: Command '['python', 'script.py', '117']' returned non-zero exit status 1.
# Erro na execução da simulação 118: Command '['python', 'script.py', '118']' returned non-zero exit status 1.
# Erro na execução da simulação 119: Command '['python', 'script.py', '119']' returned non-zero exit status 1.
# Erro na execução da simulação 120: Command '['python', 'script.py', '120']' returned non-zero exit status 1.
# Tentativa 121
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 121,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 122: Command '['python', 'script.py', '122']' returned non-zero exit status 1.
# Erro na execução da simulação 123: Command '['python', 'script.py', '123']' returned non-zero exit status 1.
# Erro na execução da simulação 124: Command '['python', 'script.py', '124']' returned non-zero exit status 1.
# Erro na execução da simulação 125: Command '['python', 'script.py', '125']' returned non-zero exit status 1.
# Tentativa 126
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 126,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 127
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 127,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 128: Command '['python', 'script.py', '128']' returned non-zero exit status 1.
# Tentativa 129
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 129,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 130: Command '['python', 'script.py', '130']' returned non-zero exit status 1.
# Erro na execução da simulação 131: Command '['python', 'script.py', '131']' returned non-zero exit status 1.
# Erro na execução da simulação 132: Command '['python', 'script.py', '132']' returned non-zero exit status 1.
# Tentativa 133
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 133,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 134: Command '['python', 'script.py', '134']' returned non-zero exit status 1.
# Tentativa 135
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 135,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 136: Command '['python', 'script.py', '136']' returned non-zero exit status 1.
# Erro na execução da simulação 137: Command '['python', 'script.py', '137']' returned non-zero exit status 1.
# Erro na execução da simulação 138: Command '['python', 'script.py', '138']' returned non-zero exit status 1.
# Erro na execução da simulação 139: Command '['python', 'script.py', '139']' returned non-zero exit status 1.
# Tentativa 140
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 140,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 141
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 141,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 142: Command '['python', 'script.py', '142']' returned non-zero exit status 1.
# Tentativa 143
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 143,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 144
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 144,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 145: Command '['python', 'script.py', '145']' returned non-zero exit status 1.
# Tentativa 146
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 146,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 147
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 147,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Tentativa 148
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 148,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 149
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 149,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 150: Command '['python', 'script.py', '150']' returned non-zero exit status 1.
# Erro na execução da simulação 151: Command '['python', 'script.py', '151']' returned non-zero exit status 1.
# Erro na execução da simulação 152: Command '['python', 'script.py', '152']' returned non-zero exit status 1.
# Erro na execução da simulação 153: Command '['python', 'script.py', '153']' returned non-zero exit status 1.
# Erro na execução da simulação 154: Command '['python', 'script.py', '154']' returned non-zero exit status 1.
# Erro na execução da simulação 155: Command '['python', 'script.py', '155']' returned non-zero exit status 1.
# Erro na execução da simulação 156: Command '['python', 'script.py', '156']' returned non-zero exit status 1.
# Erro na execução da simulação 157: Command '['python', 'script.py', '157']' returned non-zero exit status 1.
# Erro na execução da simulação 158: Command '['python', 'script.py', '158']' returned non-zero exit status 1.
# Tentativa 159
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 159,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 160: Command '['python', 'script.py', '160']' returned non-zero exit status 1.
# Erro na execução da simulação 161: Command '['python', 'script.py', '161']' returned non-zero exit status 1.
# Tentativa 162
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 162,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 163: Command '['python', 'script.py', '163']' returned non-zero exit status 1.
# Erro na execução da simulação 164: Command '['python', 'script.py', '164']' returned non-zero exit status 1.
# Tentativa 165
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 165,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 166: Command '['python', 'script.py', '166']' returned non-zero exit status 1.
# Erro na execução da simulação 167: Command '['python', 'script.py', '167']' returned non-zero exit status 1.
# Erro na execução da simulação 168: Command '['python', 'script.py', '168']' returned non-zero exit status 1.
# Erro na execução da simulação 169: Command '['python', 'script.py', '169']' returned non-zero exit status 1.
# Erro na execução da simulação 170: Command '['python', 'script.py', '170']' returned non-zero exit status 1.
# Tentativa 171
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 171,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 172: Command '['python', 'script.py', '172']' returned non-zero exit status 1.
# Erro na execução da simulação 173: Command '['python', 'script.py', '173']' returned non-zero exit status 1.
# Erro na execução da simulação 174: Command '['python', 'script.py', '174']' returned non-zero exit status 1.
# Erro na execução da simulação 175: Command '['python', 'script.py', '175']' returned non-zero exit status 1.
# Erro na execução da simulação 176: Command '['python', 'script.py', '176']' returned non-zero exit status 1.
# Tentativa 177
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 177,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 178
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 178,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 179: Command '['python', 'script.py', '179']' returned non-zero exit status 1.
# Tentativa 180
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 180,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 181: Command '['python', 'script.py', '181']' returned non-zero exit status 1.
# Erro na execução da simulação 182: Command '['python', 'script.py', '182']' returned non-zero exit status 1.
# Tentativa 183
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 183,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 184: Command '['python', 'script.py', '184']' returned non-zero exit status 1.
# Tentativa 185
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 185,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 186
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 186,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 187
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 187,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 188: Command '['python', 'script.py', '188']' returned non-zero exit status 1.
# Tentativa 189
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 189,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 190: Command '['python', 'script.py', '190']' returned non-zero exit status 1.
# Erro na execução da simulação 191: Command '['python', 'script.py', '191']' returned non-zero exit status 1.
# Erro na execução da simulação 192: Command '['python', 'script.py', '192']' returned non-zero exit status 1.
# Erro na execução da simulação 193: Command '['python', 'script.py', '193']' returned non-zero exit status 1.
# Erro na execução da simulação 194: Command '['python', 'script.py', '194']' returned non-zero exit status 1.
# Erro na execução da simulação 195: Command '['python', 'script.py', '195']' returned non-zero exit status 1.
# Erro na execução da simulação 196: Command '['python', 'script.py', '196']' returned non-zero exit status 1.
# Erro na execução da simulação 197: Command '['python', 'script.py', '197']' returned non-zero exit status 1.
# Erro na execução da simulação 198: Command '['python', 'script.py', '198']' returned non-zero exit status 1.
# Erro na execução da simulação 199: Command '['python', 'script.py', '199']' returned non-zero exit status 1.
# Erro na execução da simulação 200: Command '['python', 'script.py', '200']' returned non-zero exit status 1.
# Erro na execução da simulação 201: Command '['python', 'script.py', '201']' returned non-zero exit status 1.
# Erro na execução da simulação 202: Command '['python', 'script.py', '202']' returned non-zero exit status 1.
# Erro na execução da simulação 203: Command '['python', 'script.py', '203']' returned non-zero exit status 1.
# Tentativa 204
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 204,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 205: Command '['python', 'script.py', '205']' returned non-zero exit status 1.
# Erro na execução da simulação 206: Command '['python', 'script.py', '206']' returned non-zero exit status 1.
# Erro na execução da simulação 207: Command '['python', 'script.py', '207']' returned non-zero exit status 1.
# Erro na execução da simulação 208: Command '['python', 'script.py', '208']' returned non-zero exit status 1.
# Erro na execução da simulação 209: Command '['python', 'script.py', '209']' returned non-zero exit status 1.
# Erro na execução da simulação 210: Command '['python', 'script.py', '210']' returned non-zero exit status 1.
# Tentativa 211
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 211,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 212: Command '['python', 'script.py', '212']' returned non-zero exit status 1.
# Erro na execução da simulação 213: Command '['python', 'script.py', '213']' returned non-zero exit status 1.
# Erro na execução da simulação 214: Command '['python', 'script.py', '214']' returned non-zero exit status 1.
# Erro na execução da simulação 215: Command '['python', 'script.py', '215']' returned non-zero exit status 1.
# Erro na execução da simulação 216: Command '['python', 'script.py', '216']' returned non-zero exit status 1.
# Tentativa 217
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 217,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 218: Command '['python', 'script.py', '218']' returned non-zero exit status 1.
# Erro na execução da simulação 219: Command '['python', 'script.py', '219']' returned non-zero exit status 1.
# Erro na execução da simulação 220: Command '['python', 'script.py', '220']' returned non-zero exit status 1.
# Tentativa 221
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 221,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 222: Command '['python', 'script.py', '222']' returned non-zero exit status 1.
# Tentativa 223
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 223,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 224: Command '['python', 'script.py', '224']' returned non-zero exit status 1.
# Erro na execução da simulação 225: Command '['python', 'script.py', '225']' returned non-zero exit status 1.
# Erro na execução da simulação 226: Command '['python', 'script.py', '226']' returned non-zero exit status 1.
# Erro na execução da simulação 227: Command '['python', 'script.py', '227']' returned non-zero exit status 1.
# Erro na execução da simulação 228: Command '['python', 'script.py', '228']' returned non-zero exit status 1.
# Erro na execução da simulação 229: Command '['python', 'script.py', '229']' returned non-zero exit status 1.
# Tentativa 230
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 230,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 231: Command '['python', 'script.py', '231']' returned non-zero exit status 1.
# Erro na execução da simulação 232: Command '['python', 'script.py', '232']' returned non-zero exit status 1.
# Erro na execução da simulação 233: Command '['python', 'script.py', '233']' returned non-zero exit status 1.
# Erro na execução da simulação 234: Command '['python', 'script.py', '234']' returned non-zero exit status 1.
# Erro na execução da simulação 235: Command '['python', 'script.py', '235']' returned non-zero exit status 1.
# Erro na execução da simulação 236: Command '['python', 'script.py', '236']' returned non-zero exit status 1.
# Erro na execução da simulação 237: Command '['python', 'script.py', '237']' returned non-zero exit status 1.
# Erro na execução da simulação 238: Command '['python', 'script.py', '238']' returned non-zero exit status 1.
# Erro na execução da simulação 239: Command '['python', 'script.py', '239']' returned non-zero exit status 1.
# Erro na execução da simulação 240: Command '['python', 'script.py', '240']' returned non-zero exit status 1.
# Erro na execução da simulação 241: Command '['python', 'script.py', '241']' returned non-zero exit status 1.
# Erro na execução da simulação 242: Command '['python', 'script.py', '242']' returned non-zero exit status 1.
# Erro na execução da simulação 243: Command '['python', 'script.py', '243']' returned non-zero exit status 1.
# Tentativa 244
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 244,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 245: Command '['python', 'script.py', '245']' returned non-zero exit status 1.
# Tentativa 246
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 246,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 247: Command '['python', 'script.py', '247']' returned non-zero exit status 1.
# Tentativa 248
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 248,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 249: Command '['python', 'script.py', '249']' returned non-zero exit status 1.
# Erro na execução da simulação 250: Command '['python', 'script.py', '250']' returned non-zero exit status 1.
# Erro na execução da simulação 251: Command '['python', 'script.py', '251']' returned non-zero exit status 1.
# Tentativa 252
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 252,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 253
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 253,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 254: Command '['python', 'script.py', '254']' returned non-zero exit status 1.
# Erro na execução da simulação 255: Command '['python', 'script.py', '255']' returned non-zero exit status 1.
# Tentativa 256
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 256,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 257
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 257,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 258: Command '['python', 'script.py', '258']' returned non-zero exit status 1.
# Tentativa 259
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 259,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 260
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 260,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 261: Command '['python', 'script.py', '261']' returned non-zero exit status 1.
# Tentativa 262
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 262,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 263: Command '['python', 'script.py', '263']' returned non-zero exit status 1.
# Tentativa 264
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 264,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 265: Command '['python', 'script.py', '265']' returned non-zero exit status 1.
# Erro na execução da simulação 266: Command '['python', 'script.py', '266']' returned non-zero exit status 1.
# Erro na execução da simulação 267: Command '['python', 'script.py', '267']' returned non-zero exit status 1.
# Erro na execução da simulação 268: Command '['python', 'script.py', '268']' returned non-zero exit status 1.
# Erro na execução da simulação 269: Command '['python', 'script.py', '269']' returned non-zero exit status 1.
# Tentativa 270
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 270,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 271: Command '['python', 'script.py', '271']' returned non-zero exit status 1.
# Erro na execução da simulação 272: Command '['python', 'script.py', '272']' returned non-zero exit status 1.
# Erro na execução da simulação 273: Command '['python', 'script.py', '273']' returned non-zero exit status 1.
# Tentativa 274
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 274,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 275: Command '['python', 'script.py', '275']' returned non-zero exit status 1.
# Erro na execução da simulação 276: Command '['python', 'script.py', '276']' returned non-zero exit status 1.
# Tentativa 277
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 277,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 278: Command '['python', 'script.py', '278']' returned non-zero exit status 1.
# Erro na execução da simulação 279: Command '['python', 'script.py', '279']' returned non-zero exit status 1.
# Erro na execução da simulação 280: Command '['python', 'script.py', '280']' returned non-zero exit status 1.
# Erro na execução da simulação 281: Command '['python', 'script.py', '281']' returned non-zero exit status 1.
# Erro na execução da simulação 282: Command '['python', 'script.py', '282']' returned non-zero exit status 1.
# Erro na execução da simulação 283: Command '['python', 'script.py', '283']' returned non-zero exit status 1.
# Erro na execução da simulação 284: Command '['python', 'script.py', '284']' returned non-zero exit status 1.
# Tentativa 285
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 285,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 286: Command '['python', 'script.py', '286']' returned non-zero exit status 1.
# Erro na execução da simulação 287: Command '['python', 'script.py', '287']' returned non-zero exit status 1.
# Erro na execução da simulação 288: Command '['python', 'script.py', '288']' returned non-zero exit status 1.
# Erro na execução da simulação 289: Command '['python', 'script.py', '289']' returned non-zero exit status 1.
# Erro na execução da simulação 290: Command '['python', 'script.py', '290']' returned non-zero exit status 1.
# Erro na execução da simulação 291: Command '['python', 'script.py', '291']' returned non-zero exit status 1.
# Tentativa 292
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 292,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 293: Command '['python', 'script.py', '293']' returned non-zero exit status 1.
# Erro na execução da simulação 294: Command '['python', 'script.py', '294']' returned non-zero exit status 1.
# Erro na execução da simulação 295: Command '['python', 'script.py', '295']' returned non-zero exit status 1.
# Erro na execução da simulação 296: Command '['python', 'script.py', '296']' returned non-zero exit status 1.
# Erro na execução da simulação 297: Command '['python', 'script.py', '297']' returned non-zero exit status 1.
# Erro na execução da simulação 298: Command '['python', 'script.py', '298']' returned non-zero exit status 1.
# Tentativa 299
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 299,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 300
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 300,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 301: Command '['python', 'script.py', '301']' returned non-zero exit status 1.
# Erro na execução da simulação 302: Command '['python', 'script.py', '302']' returned non-zero exit status 1.
# Erro na execução da simulação 303: Command '['python', 'script.py', '303']' returned non-zero exit status 1.
# Erro na execução da simulação 304: Command '['python', 'script.py', '304']' returned non-zero exit status 1.
# Tentativa 305
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 305,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 306
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 306,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 307: Command '['python', 'script.py', '307']' returned non-zero exit status 1.
# Tentativa 308
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 308,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 309: Command '['python', 'script.py', '309']' returned non-zero exit status 1.
# Erro na execução da simulação 310: Command '['python', 'script.py', '310']' returned non-zero exit status 1.
# Erro na execução da simulação 311: Command '['python', 'script.py', '311']' returned non-zero exit status 1.
# Erro na execução da simulação 312: Command '['python', 'script.py', '312']' returned non-zero exit status 1.
# Erro na execução da simulação 313: Command '['python', 'script.py', '313']' returned non-zero exit status 1.
# Tentativa 314
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 314,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 315: Command '['python', 'script.py', '315']' returned non-zero exit status 1.
# Erro na execução da simulação 316: Command '['python', 'script.py', '316']' returned non-zero exit status 1.
# Erro na execução da simulação 317: Command '['python', 'script.py', '317']' returned non-zero exit status 1.
# Erro na execução da simulação 318: Command '['python', 'script.py', '318']' returned non-zero exit status 1.
# Erro na execução da simulação 319: Command '['python', 'script.py', '319']' returned non-zero exit status 1.
# Erro na execução da simulação 320: Command '['python', 'script.py', '320']' returned non-zero exit status 1.
# Erro na execução da simulação 321: Command '['python', 'script.py', '321']' returned non-zero exit status 1.
# Erro na execução da simulação 322: Command '['python', 'script.py', '322']' returned non-zero exit status 1.
# Tentativa 323
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 323,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 324: Command '['python', 'script.py', '324']' returned non-zero exit status 1.
# Tentativa 325
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 325,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 326: Command '['python', 'script.py', '326']' returned non-zero exit status 1.
# Erro na execução da simulação 327: Command '['python', 'script.py', '327']' returned non-zero exit status 1.
# Tentativa 328
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 328,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 329: Command '['python', 'script.py', '329']' returned non-zero exit status 1.
# Tentativa 330
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 330,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 331
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 331,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 332: Command '['python', 'script.py', '332']' returned non-zero exit status 1.
# Erro na execução da simulação 333: Command '['python', 'script.py', '333']' returned non-zero exit status 1.
# Tentativa 334
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 334,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 335: Command '['python', 'script.py', '335']' returned non-zero exit status 1.
# Erro na execução da simulação 336: Command '['python', 'script.py', '336']' returned non-zero exit status 1.
# Erro na execução da simulação 337: Command '['python', 'script.py', '337']' returned non-zero exit status 1.
# Erro na execução da simulação 338: Command '['python', 'script.py', '338']' returned non-zero exit status 1.
# Erro na execução da simulação 339: Command '['python', 'script.py', '339']' returned non-zero exit status 1.
# Erro na execução da simulação 340: Command '['python', 'script.py', '340']' returned non-zero exit status 1.
# Tentativa 341
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 341,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 342: Command '['python', 'script.py', '342']' returned non-zero exit status 1.
# Erro na execução da simulação 343: Command '['python', 'script.py', '343']' returned non-zero exit status 1.
# Erro na execução da simulação 344: Command '['python', 'script.py', '344']' returned non-zero exit status 1.
# Erro na execução da simulação 345: Command '['python', 'script.py', '345']' returned non-zero exit status 1.
# Erro na execução da simulação 346: Command '['python', 'script.py', '346']' returned non-zero exit status 1.
# Tentativa 347
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 347,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 348: Command '['python', 'script.py', '348']' returned non-zero exit status 1.
# Erro na execução da simulação 349: Command '['python', 'script.py', '349']' returned non-zero exit status 1.
# Tentativa 350
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 350,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 351: Command '['python', 'script.py', '351']' returned non-zero exit status 1.
# Erro na execução da simulação 352: Command '['python', 'script.py', '352']' returned non-zero exit status 1.
# Erro na execução da simulação 353: Command '['python', 'script.py', '353']' returned non-zero exit status 1.
# Erro na execução da simulação 354: Command '['python', 'script.py', '354']' returned non-zero exit status 1.
# Erro na execução da simulação 355: Command '['python', 'script.py', '355']' returned non-zero exit status 1.
# Erro na execução da simulação 356: Command '['python', 'script.py', '356']' returned non-zero exit status 1.
# Tentativa 357
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 357,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 358: Command '['python', 'script.py', '358']' returned non-zero exit status 1.
# Tentativa 359
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 359,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 360: Command '['python', 'script.py', '360']' returned non-zero exit status 1.
# Erro na execução da simulação 361: Command '['python', 'script.py', '361']' returned non-zero exit status 1.
# Erro na execução da simulação 362: Command '['python', 'script.py', '362']' returned non-zero exit status 1.
# Erro na execução da simulação 363: Command '['python', 'script.py', '363']' returned non-zero exit status 1.
# Tentativa 364
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 364,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.85,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 365: Command '['python', 'script.py', '365']' returned non-zero exit status 1.
# Erro na execução da simulação 366: Command '['python', 'script.py', '366']' returned non-zero exit status 1.
# Erro na execução da simulação 367: Command '['python', 'script.py', '367']' returned non-zero exit status 1.
# Erro na execução da simulação 368: Command '['python', 'script.py', '368']' returned non-zero exit status 1.
# Erro na execução da simulação 369: Command '['python', 'script.py', '369']' returned non-zero exit status 1.
# Erro na execução da simulação 370: Command '['python', 'script.py', '370']' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      24 attempt_count += 1
#      25 try:
#      26     # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
# ---> 27     result = subprocess.run(
#      28         ["python", "script.py", str(attempt_count)],
#      29         capture_output=True,
#      30         text=True,
#      31         check=True
#      32     )
#      34     # Filtra a saída para tentar capturar apenas o JSON
#      35     output = result.stdout.strip()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
