# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Número de sucessos desejados
success_target = 3  # Número desejado de sucessos

# Inicializa contadores
success_count = 0
attempt_count = 0

# Loop para rodar a simulação até o número desejado de sucessos
while success_count < success_target:
    attempt_count += 1
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "script.py", str(attempt_count)],
            capture_output=True,
            text=True,
            check=True
        )

        # Filtra a saída para tentar capturar apenas o JSON
        output = result.stdout.strip()

        # Exibe a inicialização das variáveis
        print(f"Tentativa {attempt_count}")
        print("Saída obtida: Hosts inicializados")
        print("Canais inicializados")
        print("Pares EPRs adicionados")

        # Filtra a parte do JSON
        json_str = ""
        try:
            # Encontra o JSON na saída
            start_idx = output.index('{')
            end_idx = output.rindex('}') + 1
            json_str = output[start_idx:end_idx]
        except ValueError:
            print(f"Tentativa {attempt_count} - Saída não contém JSON válido: {output}")
            continue
        
        # Verifica se a saída é um JSON válido
        try:
            simulation_result = json.loads(json_str)
            # Exibe o JSON com formatação bonita
            print(json.dumps(simulation_result, indent=4))
        except json.JSONDecodeError:
            print(f"Tentativa {attempt_count} - Erro ao processar JSON: {output}")
            continue
        
        # Verifica o sucesso da simulação
        if simulation_result.get("success", False):
            success_count += 1
            print(f"Simulação {attempt_count} bem-sucedida! (Sucessos: {success_count})")
        
        # Verifica se o número de sucessos desejado foi alcançado
        if success_count >= success_target:
            print(f"Alcançado o número de sucessos desejados ({success_target}). Finalizando simulações.")
            break  # Encerra o loop quando o número de sucessos for atingido

    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt_count}: {e}")
        continue

# Processa o arquivo CSV para coletar as métricas
try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 2
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Erro na execução da simulação 3: Command '['python', 'script.py', '3']' returned non-zero exit status 1.
# Tentativa 4
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 5: Command '['python', 'script.py', '5']' returned non-zero exit status 1.
# Tentativa 6
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 7: Command '['python', 'script.py', '7']' returned non-zero exit status 1.
# Tentativa 8
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 9
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 10
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 11: Command '['python', 'script.py', '11']' returned non-zero exit status 1.
# Tentativa 12
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 13
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 14
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 14,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 15: Command '['python', 'script.py', '15']' returned non-zero exit status 1.
# Erro na execução da simulação 16: Command '['python', 'script.py', '16']' returned non-zero exit status 1.
# Tentativa 17
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 18
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 19
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 20
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 21
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 22
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 23
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 24: Command '['python', 'script.py', '24']' returned non-zero exit status 1.
# Tentativa 25
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 26
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 27
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 27,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 28
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 29
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 30
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 31
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 32: Command '['python', 'script.py', '32']' returned non-zero exit status 1.
# Tentativa 33
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 33,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 34
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 35: Command '['python', 'script.py', '35']' returned non-zero exit status 1.
# Tentativa 36
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 37
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 38: Command '['python', 'script.py', '38']' returned non-zero exit status 1.
# Tentativa 39
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 40: Command '['python', 'script.py', '40']' returned non-zero exit status 1.
# Tentativa 41
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 42
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 43
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 44
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 45
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 46
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 47
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 48
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 49
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 49,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 50
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 51
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 52: Command '['python', 'script.py', '52']' returned non-zero exit status 1.
# Tentativa 53
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 54
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 55: Command '['python', 'script.py', '55']' returned non-zero exit status 1.
# Tentativa 56
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 56,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 57
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 58
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 59
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 59,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 60
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 61: Command '['python', 'script.py', '61']' returned non-zero exit status 1.
# Tentativa 62
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 63: Command '['python', 'script.py', '63']' returned non-zero exit status 1.
# Tentativa 64
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 65
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 66
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 67: Command '['python', 'script.py', '67']' returned non-zero exit status 1.
# Tentativa 68
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 69
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 69,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 70
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 71
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 72: Command '['python', 'script.py', '72']' returned non-zero exit status 1.
# Tentativa 73
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 74
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 75
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 76: Command '['python', 'script.py', '76']' returned non-zero exit status 1.
# Tentativa 77
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 78: Command '['python', 'script.py', '78']' returned non-zero exit status 1.
# Tentativa 79
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 80
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 81
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 82
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 83: Command '['python', 'script.py', '83']' returned non-zero exit status 1.
# Tentativa 84
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 85
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 86
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 87
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 88
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 89
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 89,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 90
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Erro na execução da simulação 91: Command '['python', 'script.py', '91']' returned non-zero exit status 1.
# Tentativa 92
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 93
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 94
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 95: Command '['python', 'script.py', '95']' returned non-zero exit status 1.
# Tentativa 96
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 97
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 98
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 99
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 99,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 100
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 101: Command '['python', 'script.py', '101']' returned non-zero exit status 1.
# Tentativa 102
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 102,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 103
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 103,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 104: Command '['python', 'script.py', '104']' returned non-zero exit status 1.
# Tentativa 105
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 105,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 106: Command '['python', 'script.py', '106']' returned non-zero exit status 1.
# Tentativa 107
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 107,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 108: Command '['python', 'script.py', '108']' returned non-zero exit status 1.
# Tentativa 109
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 109,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 110: Command '['python', 'script.py', '110']' returned non-zero exit status 1.
# Tentativa 111
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 111,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 112
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 112,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 113
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 113,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 114
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 114,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 115
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 115,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 116
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 116,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 117
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 117,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 118
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 118,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 119
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 119,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 120
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 120,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 121: Command '['python', 'script.py', '121']' returned non-zero exit status 1.
# Erro na execução da simulação 122: Command '['python', 'script.py', '122']' returned non-zero exit status 1.
# Tentativa 123
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 123,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 124
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 124,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 125: Command '['python', 'script.py', '125']' returned non-zero exit status 1.
# Erro na execução da simulação 126: Command '['python', 'script.py', '126']' returned non-zero exit status 1.
# Erro na execução da simulação 127: Command '['python', 'script.py', '127']' returned non-zero exit status 1.
# Tentativa 128
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 128,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 129
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 129,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 130
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 130,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 131
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 131,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 132
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 132,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 133
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 133,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 134
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 134,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 135
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 135,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 136
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 136,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 137
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 137,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 138: Command '['python', 'script.py', '138']' returned non-zero exit status 1.
# Tentativa 139
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 139,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 140
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 140,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 141
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 141,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 142
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 142,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 143: Command '['python', 'script.py', '143']' returned non-zero exit status 1.
# Tentativa 144
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 144,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 145: Command '['python', 'script.py', '145']' returned non-zero exit status 1.
# Tentativa 146
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 146,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 147
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 147,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 148
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 148,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 149
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 149,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 150
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 150,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 151
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 151,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 152
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 152,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 153: Command '['python', 'script.py', '153']' returned non-zero exit status 1.
# Tentativa 154
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 154,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 155
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 155,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Erro na execução da simulação 156: Command '['python', 'script.py', '156']' returned non-zero exit status 1.
# Erro na execução da simulação 157: Command '['python', 'script.py', '157']' returned non-zero exit status 1.
# Erro na execução da simulação 158: Command '['python', 'script.py', '158']' returned non-zero exit status 1.
# Tentativa 159
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 159,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 160
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 160,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 161
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 161,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 162
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 162,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 163: Command '['python', 'script.py', '163']' returned non-zero exit status 1.
# Erro na execução da simulação 164: Command '['python', 'script.py', '164']' returned non-zero exit status 1.
# Erro na execução da simulação 165: Command '['python', 'script.py', '165']' returned non-zero exit status 1.
# Tentativa 166
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 166,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 167
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 167,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 168
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 168,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 169
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 169,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 170
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 170,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 171: Command '['python', 'script.py', '171']' returned non-zero exit status 1.
# Tentativa 172
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 172,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 173: Command '['python', 'script.py', '173']' returned non-zero exit status 1.
# Tentativa 174
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 174,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 175
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 175,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 176
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 176,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Erro na execução da simulação 177: Command '['python', 'script.py', '177']' returned non-zero exit status 1.
# Tentativa 178
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 178,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 179
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 179,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# Tentativa 180
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 180,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 181
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 181,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 182
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 182,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 183: Command '['python', 'script.py', '183']' returned non-zero exit status 1.
# Tentativa 184
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 184,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 185: Command '['python', 'script.py', '185']' returned non-zero exit status 1.
# Erro na execução da simulação 186: Command '['python', 'script.py', '186']' returned non-zero exit status 1.
# Erro na execução da simulação 187: Command '['python', 'script.py', '187']' returned non-zero exit status 1.
# Tentativa 188
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 188,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 189
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 189,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 190
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 190,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 191
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 191,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Tentativa 192
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 192,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.594
# }
# Erro na execução da simulação 193: Command '['python', 'script.py', '193']' returned non-zero exit status 1.
# Tentativa 194
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 194,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 195
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 195,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 196
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 196,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 197
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 197,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 198
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 198,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 199
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 199,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 200
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 200,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.8254443406996741
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 27
#      24 attempt_count += 1
#      25 try:
#      26     # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
# ---> 27     result = subprocess.run(
#      28         ["python", "script.py", str(attempt_count)],
#      29         capture_output=True,
#      30         text=True,
#      31         check=True
#      32     )
#      34     # Filtra a saída para tentar capturar apenas o JSON
#      35     output = result.stdout.strip()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
