# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Número de sucessos desejados
success_target = 3  # Número desejado de sucessos

# Inicializa contadores
success_count = 0
attempt_count = 0

# Loop para rodar a simulação até o número desejado de sucessos
while success_count < success_target:
    attempt_count += 1
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "script.py", str(attempt_count)],
            capture_output=True,
            text=True,
            check=True
        )

        # Filtra a saída para tentar capturar apenas o JSON
        output = result.stdout.strip()

        # Exibe a inicialização das variáveis
        print(f"Tentativa {attempt_count}")
        print("Saída obtida: Hosts inicializados")
        print("Canais inicializados")
        print("Pares EPRs adicionados")

        # Filtra a parte do JSON
        json_str = ""
        try:
            # Encontra o JSON na saída
            start_idx = output.index('{')
            end_idx = output.rindex('}') + 1
            json_str = output[start_idx:end_idx]
        except ValueError:
            print(f"Tentativa {attempt_count} - Saída não contém JSON válido: {output}")
            continue
        
        # Verifica se a saída é um JSON válido
        try:
            simulation_result = json.loads(json_str)
            # Exibe o JSON com formatação bonita
            print(json.dumps(simulation_result, indent=4))
        except json.JSONDecodeError:
            print(f"Tentativa {attempt_count} - Erro ao processar JSON: {output}")
            continue
        
        # Verifica o sucesso da simulação
        if simulation_result.get("success", False):
            success_count += 1
            print(f"Simulação {attempt_count} bem-sucedida! (Sucessos: {success_count})")
        
        # Verifica se o número de sucessos desejado foi alcançado
        if success_count >= success_target:
            print(f"Alcançado o número de sucessos desejados ({success_target}). Finalizando simulações.")
            break  # Encerra o loop quando o número de sucessos for atingido

    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt_count}: {e}")
        continue

# Processa o arquivo CSV para coletar as métricas
try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 2
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 3
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 4
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 5
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 5,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 6
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 7
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 7,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 8
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 9
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 10: Command '['python', 'script.py', '10']' returned non-zero exit status 1.
# Tentativa 11
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 12
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 13
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 14
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 14,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 15
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 15,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 16
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 17
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 18
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 19
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 20
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 21
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 22
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": true,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.9579062138454031
# }
# Simulação 22 bem-sucedida! (Sucessos: 1)
# Tentativa 23
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 24
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 25: Command '['python', 'script.py', '25']' returned non-zero exit status 1.
# Tentativa 26
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 27: Command '['python', 'script.py', '27']' returned non-zero exit status 1.
# Tentativa 28
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": true,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.9579062138454031
# }
# Simulação 28 bem-sucedida! (Sucessos: 2)
# Tentativa 29
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 30
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 31
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 32: Command '['python', 'script.py', '32']' returned non-zero exit status 1.
# Erro na execução da simulação 33: Command '['python', 'script.py', '33']' returned non-zero exit status 1.
# Tentativa 34
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6923076923076923
# }
# Tentativa 35
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 36: Command '['python', 'script.py', '36']' returned non-zero exit status 1.
# Tentativa 37
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 38
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 39: Command '['python', 'script.py', '39']' returned non-zero exit status 1.
# Tentativa 40
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 40,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 41: Command '['python', 'script.py', '41']' returned non-zero exit status 1.
# Tentativa 42
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 43
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 44
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 45
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 46
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 47: Command '['python', 'script.py', '47']' returned non-zero exit status 1.
# Tentativa 48
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 49: Command '['python', 'script.py', '49']' returned non-zero exit status 1.
# Erro na execução da simulação 50: Command '['python', 'script.py', '50']' returned non-zero exit status 1.
# Erro na execução da simulação 51: Command '['python', 'script.py', '51']' returned non-zero exit status 1.
# Tentativa 52
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 53
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 54
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 55
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 55,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 56: Command '['python', 'script.py', '56']' returned non-zero exit status 1.
# Tentativa 57
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 58
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 59
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 59,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 60: Command '['python', 'script.py', '60']' returned non-zero exit status 1.
# Tentativa 61
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 62
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 63
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 63,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 64
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 65: Command '['python', 'script.py', '65']' returned non-zero exit status 1.
# Tentativa 66
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 67
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 68
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 69
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 69,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 70: Command '['python', 'script.py', '70']' returned non-zero exit status 1.
# Tentativa 71
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 72
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 72,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 73
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 74
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 75
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 76
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 77
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 78: Command '['python', 'script.py', '78']' returned non-zero exit status 1.
# Tentativa 79
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 80
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 81
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 82: Command '['python', 'script.py', '82']' returned non-zero exit status 1.
# Tentativa 83
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 84
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 85: Command '['python', 'script.py', '85']' returned non-zero exit status 1.
# Erro na execução da simulação 86: Command '['python', 'script.py', '86']' returned non-zero exit status 1.
# Tentativa 87
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 88
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 89: Command '['python', 'script.py', '89']' returned non-zero exit status 1.
# Tentativa 90
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 91
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 91,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 92
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 93
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 94: Command '['python', 'script.py', '94']' returned non-zero exit status 1.
# Tentativa 95
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 95,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 96: Command '['python', 'script.py', '96']' returned non-zero exit status 1.
# Tentativa 97
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 98: Command '['python', 'script.py', '98']' returned non-zero exit status 1.
# Erro na execução da simulação 99: Command '['python', 'script.py', '99']' returned non-zero exit status 1.
# Tentativa 100
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 101: Command '['python', 'script.py', '101']' returned non-zero exit status 1.
# Tentativa 102
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 102,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 103
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 103,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 104
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 104,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 105
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 105,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 106
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 106,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 107
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 107,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 108
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 108,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 109
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 109,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 110
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 110,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 111
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 111,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 112
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 112,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 113
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 113,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 114
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 114,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 115
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 115,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 116: Command '['python', 'script.py', '116']' returned non-zero exit status 1.
# Tentativa 117
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 117,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 118
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 118,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 119
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 119,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 120: Command '['python', 'script.py', '120']' returned non-zero exit status 1.
# Tentativa 121
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 121,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 122: Command '['python', 'script.py', '122']' returned non-zero exit status 1.
# Tentativa 123
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 123,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 124
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 124,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 125
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 125,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 126
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 126,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 127
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 127,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 128
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 128,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 129: Command '['python', 'script.py', '129']' returned non-zero exit status 1.
# Erro na execução da simulação 130: Command '['python', 'script.py', '130']' returned non-zero exit status 1.
# Tentativa 131
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 131,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 132
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 132,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 133: Command '['python', 'script.py', '133']' returned non-zero exit status 1.
# Erro na execução da simulação 134: Command '['python', 'script.py', '134']' returned non-zero exit status 1.
# Erro na execução da simulação 135: Command '['python', 'script.py', '135']' returned non-zero exit status 1.
# Tentativa 136
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 136,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 137: Command '['python', 'script.py', '137']' returned non-zero exit status 1.
# Tentativa 138
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 138,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 139
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 139,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6923076923076923
# }
# Tentativa 140
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 140,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 141
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 141,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 142
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 142,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 143
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 143,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6923076923076923
# }
# Tentativa 144
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 144,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 145
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 145,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 146
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 146,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6923076923076923
# }
# Erro na execução da simulação 147: Command '['python', 'script.py', '147']' returned non-zero exit status 1.
# Erro na execução da simulação 148: Command '['python', 'script.py', '148']' returned non-zero exit status 1.
# Erro na execução da simulação 149: Command '['python', 'script.py', '149']' returned non-zero exit status 1.
# Tentativa 150
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 150,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 151
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 151,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6923076923076923
# }
# Tentativa 152
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 152,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 153
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 153,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 154
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 154,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 155
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 155,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 156
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 156,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 157
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 157,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 158
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 158,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 159: Command '['python', 'script.py', '159']' returned non-zero exit status 1.
# Tentativa 160
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 160,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Erro na execução da simulação 161: Command '['python', 'script.py', '161']' returned non-zero exit status 1.
# Tentativa 162
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 162,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 163
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 163,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 164
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 164,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Y",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 165
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 165,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "Z",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.6
# }
# Tentativa 166
# Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 166,
#     "success": true,
#     "estimated_rounds": 3,
#     "request": 0.95,
#     "channel_info": "X",
#     "initial_fidelity": 0.6,
#     "final_fidelity": 0.9579062138454031
# }
# Simulação 166 bem-sucedida! (Sucessos: 3)
# Alcançado o número de sucessos desejados (3). Finalizando simulações.
#
# Resumo das Métricas da Simulação (após todas as tentativas):
# Total de Timeslots: 14
# Total de EPRs Criados: 0
# Total de EPRs Consumidos: 508
# Fidelidade Média Total: 0.6969225273025531
