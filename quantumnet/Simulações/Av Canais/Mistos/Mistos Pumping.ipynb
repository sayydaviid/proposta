# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(100):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "Mistos.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8243339655500546,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 2
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8319912809284443,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 3
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8615951539536857,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 4
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.879225037272217,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 5
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 5,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7996033957458984,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 6
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8375511165586412,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 7
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 7,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8806447194559972,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 8
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7645778822704922,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 9
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8614381216621885,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 10
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8621973274015142,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8405674744087155,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 12
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9520962650308518,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7621161511685269,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 14
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 14,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8976128761886569,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 15
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 15,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8156614165737054,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 16
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9370492615897754,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7269069268581937
# }
# Tentativa 17
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7906754935808077,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 18
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8124620298295493,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 19
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9141681917283653,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 20
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.944799311105719,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 21
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8753737393436636,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8720733145195667,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 23
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9475650831002473,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6656930349299999
# }
# Tentativa 24
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8368568297149723,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 25
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8920123407382241,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8647556524626558,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 27
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 27,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8588024672098528,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9056040879564069,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 29
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7849456859630576,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8134538285329186,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 31
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8028491950204425,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 32
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 32,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9399626890628971,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 33
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 33,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8322510638252212,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 34
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7961053236434785,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 35
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7931638617564079,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 36
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7958228457876005,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 37
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8276693328044576,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 38
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8388830038291719,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 39
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8814760671887828,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 40
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 40,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7606816991422714,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 41
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.931454312349939,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8390443679178319,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9462701935636457,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 44
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8358991680386456,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 45
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8158862132004342,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 46
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8504389717732943,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 47
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9079908531504579,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 48
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7544041982133465,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 49
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 49,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8368201965567744,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8346938690284855,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 51
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7950185282387695,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 52
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8430274014122979,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 53
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8052100426160279,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 54
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8466033211200157,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 55
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 55,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7574964173660913,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 56
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 56,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8307034271275172,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 57
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8332483145275837,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 58
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9165636235969683,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 59
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 59,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8408483589734302,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 60
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8336019876725339,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7866910202333774,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9192941865640374,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 63
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 63,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.758775752336588,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 64
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7682369242611562,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 65
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.782074990114798,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 66
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9023944073627653,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7417480845027985
# }
# Tentativa 67
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8717696427978323,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 68
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8282623016532924,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 69
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 69,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7933380819464309,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 70
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9531235947588025,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 71
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7616559674163476,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 72
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 72,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8578318972468738,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 73
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8856081879590182,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 74
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8584991830081757,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9004735248102191,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 76
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9395547416053176,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 77
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7981983826751808,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 78
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7951630060525786,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 79
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.909007200414742,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 80
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8732161596064899,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 81
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7882454636612215,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 82
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8872949749886181,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 83
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.7533330501313347,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 84
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9045729359277563,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 85
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8191393269354632,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 86
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8514141488082781,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 87
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7752311053137109,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 88
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7870814914951693,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 89
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 89,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8511014737342899,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8513064864283165,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 91
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 91,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7892728450365186,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8093651560274072,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 93
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8711698645033569,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 94
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8575941552421781,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 95
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 95,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8562098058630926,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9130752847198336,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 97
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9531411626379804,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 98
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9471714815835978,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 99
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 99,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7591285160201023,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 100
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9059810973886453,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
#
# Resumo das Métricas da Simulação (após todas as tentativas):
# Total de Timeslots: 110
# Total de EPRs Criados: 0
# Total de EPRs Consumidos: 338
# Fidelidade Média Total: 0.8202566143204846
