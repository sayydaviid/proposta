# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(410):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "XYZ.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8584921507883359,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 2
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9041645643582018,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 3
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8674612974579919,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 4
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.944256247564789,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 5: Command '['python', 'XYZ.py', '5']' returned non-zero exit status 1.
# Tentativa 6
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.834853384996785,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 7: Command '['python', 'XYZ.py', '7']' returned non-zero exit status 1.
# Tentativa 8
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9020262944995245,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 9
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.884107098021366,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 10
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.813662028335974,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8331543317036099,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 12: Command '['python', 'XYZ.py', '12']' returned non-zero exit status 1.
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9202587641130073,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 14: Command '['python', 'XYZ.py', '14']' returned non-zero exit status 1.
# Tentativa 15
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 15,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.824071796244536,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 16
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8666789326452603,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 17
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9516745857694876,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 18
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8507014042385617,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 19: Command '['python', 'XYZ.py', '19']' returned non-zero exit status 1.
# Tentativa 20
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9294527752841608,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 21
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8830392130259506,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9251221981575047,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 23: Command '['python', 'XYZ.py', '23']' returned non-zero exit status 1.
# Tentativa 24
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8452976299029317,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 25
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.910215670918044,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8593719710328799,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 27: Command '['python', 'XYZ.py', '27']' returned non-zero exit status 1.
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8170251865530156,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 29
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9350322176018315,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9098528846332292,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 31
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9101140711752305,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 32
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 32,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9179076221206066,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 33
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 33,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9357427116618843,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 34: Command '['python', 'XYZ.py', '34']' returned non-zero exit status 1.
# Tentativa 35
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8805287526835976,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 36: Command '['python', 'XYZ.py', '36']' returned non-zero exit status 1.
# Tentativa 37
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8361567975728075,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 38
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9094687374801577,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 39
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9356820774633918,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 40
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 40,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8444565394969863,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 41
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9381777225352422,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8676229506789525,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9228076212846188,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 44: Command '['python', 'XYZ.py', '44']' returned non-zero exit status 1.
# Tentativa 45
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8222311805006487,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 46: Command '['python', 'XYZ.py', '46']' returned non-zero exit status 1.
# Tentativa 47
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8291841418751915,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 48: Command '['python', 'XYZ.py', '48']' returned non-zero exit status 1.
# Erro na execução da simulação 49: Command '['python', 'XYZ.py', '49']' returned non-zero exit status 1.
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8549759842649517,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 51
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8508492518344576,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 52
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9213517780001728,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 53: Command '['python', 'XYZ.py', '53']' returned non-zero exit status 1.
# Erro na execução da simulação 54: Command '['python', 'XYZ.py', '54']' returned non-zero exit status 1.
# Erro na execução da simulação 55: Command '['python', 'XYZ.py', '55']' returned non-zero exit status 1.
# Tentativa 56
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 56,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8069708775555101,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 57
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8826558049302416,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 58
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.841695331485538,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 59: Command '['python', 'XYZ.py', '59']' returned non-zero exit status 1.
# Tentativa 60
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9319526316980908,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8566422196083741,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8963033987278362,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 63: Command '['python', 'XYZ.py', '63']' returned non-zero exit status 1.
# Tentativa 64
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8627492151423657,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 65
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9447522032120677,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 66
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9028945362065729,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 67
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9079619147638627,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 68
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8463297853950561,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 69: Command '['python', 'XYZ.py', '69']' returned non-zero exit status 1.
# Tentativa 70
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9402588121316993,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 71: Command '['python', 'XYZ.py', '71']' returned non-zero exit status 1.
# Tentativa 72
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 72,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8715620694278029,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 73
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8033855904418868,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 74
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9226582326803923,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9462989999636264,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 76
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8846335342625488,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 77
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9449198373312164,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 78
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9588770499659567,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 79
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8567443164149927,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 80: Command '['python', 'XYZ.py', '80']' returned non-zero exit status 1.
# Tentativa 81
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8676954689805502,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 82: Command '['python', 'XYZ.py', '82']' returned non-zero exit status 1.
# Tentativa 83
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9463561537111339,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 84
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8643059330339313,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 85: Command '['python', 'XYZ.py', '85']' returned non-zero exit status 1.
# Erro na execução da simulação 86: Command '['python', 'XYZ.py', '86']' returned non-zero exit status 1.
# Tentativa 87
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9538152296310947,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 88
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8961712618259599,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 89: Command '['python', 'XYZ.py', '89']' returned non-zero exit status 1.
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9538127890269132,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 91: Command '['python', 'XYZ.py', '91']' returned non-zero exit status 1.
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9544880074276663,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 93
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.939240906757201,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 94
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8032994017851189,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 95: Command '['python', 'XYZ.py', '95']' returned non-zero exit status 1.
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8667013079820352,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 97: Command '['python', 'XYZ.py', '97']' returned non-zero exit status 1.
# Tentativa 98
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9049404245013297,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 99: Command '['python', 'XYZ.py', '99']' returned non-zero exit status 1.
# Tentativa 100
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8076797339339369,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 101
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 101,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8683457746199792,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 102
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 102,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9110236497794844,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 103
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 103,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8561629666877626,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 104
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 104,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.810107186927319,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 105
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 105,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.920067185332246,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 106
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 106,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9072816537020558,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 107
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 107,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8283443797741987,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 108: Command '['python', 'XYZ.py', '108']' returned non-zero exit status 1.
# Tentativa 109
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 109,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8416668070262127,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 110
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 110,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9491753459483543,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 111
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 111,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8119656585500832,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 112
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 112,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8398706500871473,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 113
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 113,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8506177541718131,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Erro na execução da simulação 114: Command '['python', 'XYZ.py', '114']' returned non-zero exit status 1.
# Tentativa 115
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 115,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9355692263050644,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 116
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 116,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8741485689395713,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 117
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 117,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8033926356070736,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 118
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 118,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8956367472979686,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 119
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 119,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.936923700047402,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 120
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 120,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8344968045785686,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 121: Command '['python', 'XYZ.py', '121']' returned non-zero exit status 1.
# Tentativa 122
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 122,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9452794180528254,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 123: Command '['python', 'XYZ.py', '123']' returned non-zero exit status 1.
# Tentativa 124
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 124,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.921683976025366,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 125
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 125,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9424526706291377,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 126
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 126,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9426325182426678,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 127
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 127,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8766898853593956,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 128
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 128,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8280314818876313,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 129
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 129,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8822918786607236,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 130
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 130,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9125462382166513,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 131: Command '['python', 'XYZ.py', '131']' returned non-zero exit status 1.
# Erro na execução da simulação 132: Command '['python', 'XYZ.py', '132']' returned non-zero exit status 1.
# Tentativa 133
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 133,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.876237432076781,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 134
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 134,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8429223007202273,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#      16 for attempt in range(410):
#      17     try:
#      18         # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
# ---> 19         result = subprocess.run(
#      20             ["python", "XYZ.py", str(attempt + 1)],
#      21             capture_output=True,
#      22             text=True,
#      23             check=True
#      24         )
#      26         # Verifica se a saída é JSON válida
#      27         simulation_result = json.loads(result.stdout.strip())
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
