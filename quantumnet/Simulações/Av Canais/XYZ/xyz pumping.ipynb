# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(410):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "XYZ.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Erro na execução da simulação 1: Command '['python', 'XYZ.py', '1']' returned non-zero exit status 1.
# Erro na execução da simulação 2: Command '['python', 'XYZ.py', '2']' returned non-zero exit status 1.
# Erro na execução da simulação 3: Command '['python', 'XYZ.py', '3']' returned non-zero exit status 1.
# Tentativa 4
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9131104815320665,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 5
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 5,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.947708258970823,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 6
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8274284879597963,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 7
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 7,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8092252805899691,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 8: Command '['python', 'XYZ.py', '8']' returned non-zero exit status 1.
# Tentativa 9
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8466233652290233,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 10
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8420071941087413,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9206825156661997,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 12
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8438718666575327,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9267660402316884,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 14: Command '['python', 'XYZ.py', '14']' returned non-zero exit status 1.
# Erro na execução da simulação 15: Command '['python', 'XYZ.py', '15']' returned non-zero exit status 1.
# Erro na execução da simulação 16: Command '['python', 'XYZ.py', '16']' returned non-zero exit status 1.
# Tentativa 17
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8957633803425906,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 18
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8515125742514593,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 19
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8033686842715689,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 20: Command '['python', 'XYZ.py', '20']' returned non-zero exit status 1.
# Tentativa 21
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.814147718195118,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9112027184815206,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 23
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8906186219759988,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 24
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.957766874385279,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 25
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8063348345868674,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9337545247438718,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 27: Command '['python', 'XYZ.py', '27']' returned non-zero exit status 1.
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8065383292812704,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 29
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8654999979476482,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8792882170824352,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 31
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8568952801937781,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 32: Command '['python', 'XYZ.py', '32']' returned non-zero exit status 1.
# Erro na execução da simulação 33: Command '['python', 'XYZ.py', '33']' returned non-zero exit status 1.
# Tentativa 34
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8863942096939198,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 35
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8491993437766502,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 36
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.89442297798296,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 37
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9106887759076585,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 38
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9495540799968831,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 39
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9083862187561448,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 40: Command '['python', 'XYZ.py', '40']' returned non-zero exit status 1.
# Tentativa 41
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8191289953764539,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8671866660364146,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8685377392590102,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 44
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8614090775626896,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 45: Command '['python', 'XYZ.py', '45']' returned non-zero exit status 1.
# Tentativa 46
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8677846990971064,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 47: Command '['python', 'XYZ.py', '47']' returned non-zero exit status 1.
# Tentativa 48
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8892739131013812,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 49: Command '['python', 'XYZ.py', '49']' returned non-zero exit status 1.
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8142439380193065,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 51
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9556176185161396,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 52
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8824469395119947,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 53
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8640743333820151,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 54
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8392350912382939,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 55
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 55,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8980262576895542,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 56: Command '['python', 'XYZ.py', '56']' returned non-zero exit status 1.
# Tentativa 57
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8284531487687418,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 58
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8598661032536707,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 59: Command '['python', 'XYZ.py', '59']' returned non-zero exit status 1.
# Tentativa 60
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8271021153323449,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8431766413871047,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8929076043845139,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 63: Command '['python', 'XYZ.py', '63']' returned non-zero exit status 1.
# Tentativa 64
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8563938792893127,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 65
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9366968442816306,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 66
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8042454198927449,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 67
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9420103320157283,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 68
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8383701947624957,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 69: Command '['python', 'XYZ.py', '69']' returned non-zero exit status 1.
# Tentativa 70
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8651431851872187,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 71
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.826404086812239,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Erro na execução da simulação 72: Command '['python', 'XYZ.py', '72']' returned non-zero exit status 1.
# Tentativa 73
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8300886774697601,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 74
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8596892708316123,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8007716705215102,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 76: Command '['python', 'XYZ.py', '76']' returned non-zero exit status 1.
# Erro na execução da simulação 77: Command '['python', 'XYZ.py', '77']' returned non-zero exit status 1.
# Tentativa 78
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.834112649989698,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 79
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9347027142165276,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 80: Command '['python', 'XYZ.py', '80']' returned non-zero exit status 1.
# Tentativa 81
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9492976909312008,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 82
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9415445286251488,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 83
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9104369034938813,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 84: Command '['python', 'XYZ.py', '84']' returned non-zero exit status 1.
# Tentativa 85
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8308840782455099,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 86
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9295223970217895,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 87: Command '['python', 'XYZ.py', '87']' returned non-zero exit status 1.
# Tentativa 88
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8976176450449336,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 89
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 89,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8795157450851316,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8310421581272897,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 91
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 91,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9579250847675593,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8967452637698613,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 93
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9261483304995839,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 94
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8137979418787737,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 95: Command '['python', 'XYZ.py', '95']' returned non-zero exit status 1.
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8802275365997564,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 97
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8209994976657158,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 98
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8741496194997639,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 99
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 99,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9518245292947984,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 100
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9220399038835199,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 101
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 101,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.927120982929804,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 102
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 102,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9339060534736018,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 103: Command '['python', 'XYZ.py', '103']' returned non-zero exit status 1.
# Erro na execução da simulação 104: Command '['python', 'XYZ.py', '104']' returned non-zero exit status 1.
# Tentativa 105
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 105,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9172506390963964,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 106
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 106,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9022315678965729,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 107: Command '['python', 'XYZ.py', '107']' returned non-zero exit status 1.
# Tentativa 108
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 108,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9597775841966195,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 109
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 109,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9240269246762634,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 110: Command '['python', 'XYZ.py', '110']' returned non-zero exit status 1.
# Erro na execução da simulação 111: Command '['python', 'XYZ.py', '111']' returned non-zero exit status 1.
# Tentativa 112
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 112,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8521474991387336,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 113
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 113,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9206720646017604,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 114: Command '['python', 'XYZ.py', '114']' returned non-zero exit status 1.
# Erro na execução da simulação 115: Command '['python', 'XYZ.py', '115']' returned non-zero exit status 1.
# Tentativa 116
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 116,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8306311603709514,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 117
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 117,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8677327770598707,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 118
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 118,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.902044697868738,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 119
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 119,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8892215957719187,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 120
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 120,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9460057472761242,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 121
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 121,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8742108281109073,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 122
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 122,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8257585208337063,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 123
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 123,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9185661492438213,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 124
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 124,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.937550705050412,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 125: Command '['python', 'XYZ.py', '125']' returned non-zero exit status 1.
# Tentativa 126
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 126,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9032380062980677,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 127
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 127,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9059487804713255,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 128
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 128,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8710443521856369,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 129
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 129,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9568302914821576,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 130
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 130,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8962592961385892,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Erro na execução da simulação 131: Command '['python', 'XYZ.py', '131']' returned non-zero exit status 1.
# Erro na execução da simulação 132: Command '['python', 'XYZ.py', '132']' returned non-zero exit status 1.
# Tentativa 133
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 133,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9359743074738253,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 134: Command '['python', 'XYZ.py', '134']' returned non-zero exit status 1.
# Tentativa 135
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 135,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9387859068374945,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 136: Command '['python', 'XYZ.py', '136']' returned non-zero exit status 1.
# Erro na execução da simulação 137: Command '['python', 'XYZ.py', '137']' returned non-zero exit status 1.
# Tentativa 138
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 138,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8283685373002189,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 139
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 139,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8916061625354555,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 140
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 140,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8121142699639949,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 141
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 141,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9081279882531333,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 142
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 142,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.891623208609308,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 143
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 143,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.868057214145616,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 144
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 144,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8285056820112151,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      16 for attempt in range(410):
#      17     try:
#      18         # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
# ---> 19         result = subprocess.run(
#      20             ["python", "XYZ.py", str(attempt + 1)],
#      21             capture_output=True,
#      22             text=True,
#      23             check=True
#      24         )
#      26         # Verifica se a saída é JSON válida
#      27         simulation_result = json.loads(result.stdout.strip())
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\Tavares\AppData\Local\Programs\Python\Python312\Lib\threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
