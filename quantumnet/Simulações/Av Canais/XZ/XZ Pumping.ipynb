# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(410):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "XZ.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7880130699580599,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 2
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7962046279502671,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 3: Command '['python', 'XZ.py', '3']' returned non-zero exit status 1.
# Erro na execução da simulação 4: Command '['python', 'XZ.py', '4']' returned non-zero exit status 1.
# Erro na execução da simulação 5: Command '['python', 'XZ.py', '5']' returned non-zero exit status 1.
# Erro na execução da simulação 6: Command '['python', 'XZ.py', '6']' returned non-zero exit status 1.
# Erro na execução da simulação 7: Command '['python', 'XZ.py', '7']' returned non-zero exit status 1.
# Erro na execução da simulação 8: Command '['python', 'XZ.py', '8']' returned non-zero exit status 1.
# Erro na execução da simulação 9: Command '['python', 'XZ.py', '9']' returned non-zero exit status 1.
# Erro na execução da simulação 10: Command '['python', 'XZ.py', '10']' returned non-zero exit status 1.
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8097924097111104,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 12
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8831403884007948,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8474011628623282,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 14: Command '['python', 'XZ.py', '14']' returned non-zero exit status 1.
# Erro na execução da simulação 15: Command '['python', 'XZ.py', '15']' returned non-zero exit status 1.
# Tentativa 16
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7615658558032014,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 17: Command '['python', 'XZ.py', '17']' returned non-zero exit status 1.
# Erro na execução da simulação 18: Command '['python', 'XZ.py', '18']' returned non-zero exit status 1.
# Erro na execução da simulação 19: Command '['python', 'XZ.py', '19']' returned non-zero exit status 1.
# Erro na execução da simulação 20: Command '['python', 'XZ.py', '20']' returned non-zero exit status 1.
# Erro na execução da simulação 21: Command '['python', 'XZ.py', '21']' returned non-zero exit status 1.
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8789793060760211,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 23
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8287844670641636,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 24: Command '['python', 'XZ.py', '24']' returned non-zero exit status 1.
# Erro na execução da simulação 25: Command '['python', 'XZ.py', '25']' returned non-zero exit status 1.
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8430217439163108,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 27
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 27,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8332879514594476,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7765080057580914,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 29: Command '['python', 'XZ.py', '29']' returned non-zero exit status 1.
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7515493990084801,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 31: Command '['python', 'XZ.py', '31']' returned non-zero exit status 1.
# Erro na execução da simulação 32: Command '['python', 'XZ.py', '32']' returned non-zero exit status 1.
# Erro na execução da simulação 33: Command '['python', 'XZ.py', '33']' returned non-zero exit status 1.
# Tentativa 34
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8362175882445693,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 35: Command '['python', 'XZ.py', '35']' returned non-zero exit status 1.
# Erro na execução da simulação 36: Command '['python', 'XZ.py', '36']' returned non-zero exit status 1.
# Erro na execução da simulação 37: Command '['python', 'XZ.py', '37']' returned non-zero exit status 1.
# Erro na execução da simulação 38: Command '['python', 'XZ.py', '38']' returned non-zero exit status 1.
# Erro na execução da simulação 39: Command '['python', 'XZ.py', '39']' returned non-zero exit status 1.
# Erro na execução da simulação 40: Command '['python', 'XZ.py', '40']' returned non-zero exit status 1.
# Erro na execução da simulação 41: Command '['python', 'XZ.py', '41']' returned non-zero exit status 1.
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8051039060383158,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8385709158928008,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 44
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8711626804594482,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 45: Command '['python', 'XZ.py', '45']' returned non-zero exit status 1.
# Erro na execução da simulação 46: Command '['python', 'XZ.py', '46']' returned non-zero exit status 1.
# Tentativa 47
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8420795830970066,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 48: Command '['python', 'XZ.py', '48']' returned non-zero exit status 1.
# Tentativa 49
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 49,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8277619675833839,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8334314672614006,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 51: Command '['python', 'XZ.py', '51']' returned non-zero exit status 1.
# Erro na execução da simulação 52: Command '['python', 'XZ.py', '52']' returned non-zero exit status 1.
# Erro na execução da simulação 53: Command '['python', 'XZ.py', '53']' returned non-zero exit status 1.
# Tentativa 54
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7751956574414877,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 55: Command '['python', 'XZ.py', '55']' returned non-zero exit status 1.
# Erro na execução da simulação 56: Command '['python', 'XZ.py', '56']' returned non-zero exit status 1.
# Erro na execução da simulação 57: Command '['python', 'XZ.py', '57']' returned non-zero exit status 1.
# Erro na execução da simulação 58: Command '['python', 'XZ.py', '58']' returned non-zero exit status 1.
# Erro na execução da simulação 59: Command '['python', 'XZ.py', '59']' returned non-zero exit status 1.
# Erro na execução da simulação 60: Command '['python', 'XZ.py', '60']' returned non-zero exit status 1.
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7974287879006791,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8812600569370705,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 63: Command '['python', 'XZ.py', '63']' returned non-zero exit status 1.
# Erro na execução da simulação 64: Command '['python', 'XZ.py', '64']' returned non-zero exit status 1.
# Erro na execução da simulação 65: Command '['python', 'XZ.py', '65']' returned non-zero exit status 1.
# Erro na execução da simulação 66: Command '['python', 'XZ.py', '66']' returned non-zero exit status 1.
# Erro na execução da simulação 67: Command '['python', 'XZ.py', '67']' returned non-zero exit status 1.
# Erro na execução da simulação 68: Command '['python', 'XZ.py', '68']' returned non-zero exit status 1.
# Erro na execução da simulação 69: Command '['python', 'XZ.py', '69']' returned non-zero exit status 1.
# Erro na execução da simulação 70: Command '['python', 'XZ.py', '70']' returned non-zero exit status 1.
# Erro na execução da simulação 71: Command '['python', 'XZ.py', '71']' returned non-zero exit status 1.
# Erro na execução da simulação 72: Command '['python', 'XZ.py', '72']' returned non-zero exit status 1.
# Erro na execução da simulação 73: Command '['python', 'XZ.py', '73']' returned non-zero exit status 1.
# Erro na execução da simulação 74: Command '['python', 'XZ.py', '74']' returned non-zero exit status 1.
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8825773414773891,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 76: Command '['python', 'XZ.py', '76']' returned non-zero exit status 1.
# Erro na execução da simulação 77: Command '['python', 'XZ.py', '77']' returned non-zero exit status 1.
# Erro na execução da simulação 78: Command '['python', 'XZ.py', '78']' returned non-zero exit status 1.
# Erro na execução da simulação 79: Command '['python', 'XZ.py', '79']' returned non-zero exit status 1.
# Erro na execução da simulação 80: Command '['python', 'XZ.py', '80']' returned non-zero exit status 1.
# Erro na execução da simulação 81: Command '['python', 'XZ.py', '81']' returned non-zero exit status 1.
# Erro na execução da simulação 82: Command '['python', 'XZ.py', '82']' returned non-zero exit status 1.
# Erro na execução da simulação 83: Command '['python', 'XZ.py', '83']' returned non-zero exit status 1.
# Erro na execução da simulação 84: Command '['python', 'XZ.py', '84']' returned non-zero exit status 1.
# Erro na execução da simulação 85: Command '['python', 'XZ.py', '85']' returned non-zero exit status 1.
# Tentativa 86
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.7508217487743117,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 87: Command '['python', 'XZ.py', '87']' returned non-zero exit status 1.
# Erro na execução da simulação 88: Command '['python', 'XZ.py', '88']' returned non-zero exit status 1.
# Erro na execução da simulação 89: Command '['python', 'XZ.py', '89']' returned non-zero exit status 1.
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8547696438999298,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 91: Command '['python', 'XZ.py', '91']' returned non-zero exit status 1.
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8353054060747146,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 93: Command '['python', 'XZ.py', '93']' returned non-zero exit status 1.
# Erro na execução da simulação 94: Command '['python', 'XZ.py', '94']' returned non-zero exit status 1.
# Erro na execução da simulação 95: Command '['python', 'XZ.py', '95']' returned non-zero exit status 1.
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7704928383588112,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 97: Command '['python', 'XZ.py', '97']' returned non-zero exit status 1.
# Erro na execução da simulação 98: Command '['python', 'XZ.py', '98']' returned non-zero exit status 1.
# Erro na execução da simulação 99: Command '['python', 'XZ.py', '99']' returned non-zero exit status 1.
# Erro na execução da simulação 100: Command '['python', 'XZ.py', '100']' returned non-zero exit status 1.
# Tentativa 101
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 101,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7723330816532712,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 102
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 102,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8357264316686356,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 103
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 103,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7664828076680668,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 104
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 104,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8995885150676037,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 105
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 105,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8809614018098392,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 106: Command '['python', 'XZ.py', '106']' returned non-zero exit status 1.
# Erro na execução da simulação 107: Command '['python', 'XZ.py', '107']' returned non-zero exit status 1.
# Erro na execução da simulação 108: Command '['python', 'XZ.py', '108']' returned non-zero exit status 1.
# Tentativa 109
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 109,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.822868379112873,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 110
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 110,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8500222943789487,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 111: Command '['python', 'XZ.py', '111']' returned non-zero exit status 1.
# Erro na execução da simulação 112: Command '['python', 'XZ.py', '112']' returned non-zero exit status 1.
# Erro na execução da simulação 113: Command '['python', 'XZ.py', '113']' returned non-zero exit status 1.
# Tentativa 114
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 114,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8517113799934498,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 115: Command '['python', 'XZ.py', '115']' returned non-zero exit status 1.
# Erro na execução da simulação 116: Command '['python', 'XZ.py', '116']' returned non-zero exit status 1.
# Erro na execução da simulação 117: Command '['python', 'XZ.py', '117']' returned non-zero exit status 1.
# Erro na execução da simulação 118: Command '['python', 'XZ.py', '118']' returned non-zero exit status 1.
# Tentativa 119
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 119,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.797164846996821,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 120: Command '['python', 'XZ.py', '120']' returned non-zero exit status 1.
# Erro na execução da simulação 121: Command '['python', 'XZ.py', '121']' returned non-zero exit status 1.
# Tentativa 122
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 122,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8008655317590385,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Tentativa 123
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 123,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7594446812866875,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 124: Command '['python', 'XZ.py', '124']' returned non-zero exit status 1.
# Erro na execução da simulação 125: Command '['python', 'XZ.py', '125']' returned non-zero exit status 1.
# Erro na execução da simulação 126: Command '['python', 'XZ.py', '126']' returned non-zero exit status 1.
# Erro na execução da simulação 127: Command '['python', 'XZ.py', '127']' returned non-zero exit status 1.
# Erro na execução da simulação 128: Command '['python', 'XZ.py', '128']' returned non-zero exit status 1.
# Erro na execução da simulação 129: Command '['python', 'XZ.py', '129']' returned non-zero exit status 1.
# Tentativa 130
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 130,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.868801403755406,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 131: Command '['python', 'XZ.py', '131']' returned non-zero exit status 1.
# Tentativa 132
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 132,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.7502127872932026,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 133: Command '['python', 'XZ.py', '133']' returned non-zero exit status 1.
# Erro na execução da simulação 134: Command '['python', 'XZ.py', '134']' returned non-zero exit status 1.
# Erro na execução da simulação 135: Command '['python', 'XZ.py', '135']' returned non-zero exit status 1.
# Erro na execução da simulação 136: Command '['python', 'XZ.py', '136']' returned non-zero exit status 1.
# Tentativa 137
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 137,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7970103026587729,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 138: Command '['python', 'XZ.py', '138']' returned non-zero exit status 1.
# Tentativa 139
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 139,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7568149491199444,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 140
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 140,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.891591170241919,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 141
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 141,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8260975894041361,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 142: Command '['python', 'XZ.py', '142']' returned non-zero exit status 1.
# Tentativa 143
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 143,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7503844258945332,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 144: Command '['python', 'XZ.py', '144']' returned non-zero exit status 1.
# Erro na execução da simulação 145: Command '['python', 'XZ.py', '145']' returned non-zero exit status 1.
# Erro na execução da simulação 146: Command '['python', 'XZ.py', '146']' returned non-zero exit status 1.
# Tentativa 147
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 147,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8490759943205921,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 148
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 148,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7692518860185169,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 149
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 149,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8445617694328921,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 150: Command '['python', 'XZ.py', '150']' returned non-zero exit status 1.
# Erro na execução da simulação 151: Command '['python', 'XZ.py', '151']' returned non-zero exit status 1.
# Erro na execução da simulação 152: Command '['python', 'XZ.py', '152']' returned non-zero exit status 1.
# Erro na execução da simulação 153: Command '['python', 'XZ.py', '153']' returned non-zero exit status 1.
# Erro na execução da simulação 154: Command '['python', 'XZ.py', '154']' returned non-zero exit status 1.
# Erro na execução da simulação 155: Command '['python', 'XZ.py', '155']' returned non-zero exit status 1.
# Erro na execução da simulação 156: Command '['python', 'XZ.py', '156']' returned non-zero exit status 1.
# Tentativa 157
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 157,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8297484415893134,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Tentativa 158
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 158,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8502662083791991,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7483031259830853
# }
# Erro na execução da simulação 159: Command '['python', 'XZ.py', '159']' returned non-zero exit status 1.
# Tentativa 160
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 160,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8562978471714248,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 161: Command '['python', 'XZ.py', '161']' returned non-zero exit status 1.
# Erro na execução da simulação 162: Command '['python', 'XZ.py', '162']' returned non-zero exit status 1.
# Erro na execução da simulação 163: Command '['python', 'XZ.py', '163']' returned non-zero exit status 1.
# Erro na execução da simulação 164: Command '['python', 'XZ.py', '164']' returned non-zero exit status 1.
# Tentativa 165
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 165,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.881402316391259,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Erro na execução da simulação 166: Command '['python', 'XZ.py', '166']' returned non-zero exit status 1.
# Erro na execução da simulação 167: Command '['python', 'XZ.py', '167']' returned non-zero exit status 1.
# Erro na execução da simulação 168: Command '['python', 'XZ.py', '168']' returned non-zero exit status 1.
# Erro na execução da simulação 169: Command '['python', 'XZ.py', '169']' returned non-zero exit status 1.
# Tentativa 170
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 170,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8159544323714898,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 171
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 171,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8660786996433234,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 172
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 172,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8482825742133115,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Tentativa 173
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 173,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8189397265337284,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Tentativa 174
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 174,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7917015146749434,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 175
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 175,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7705284251915503,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 176: Command '['python', 'XZ.py', '176']' returned non-zero exit status 1.
# Erro na execução da simulação 177: Command '['python', 'XZ.py', '177']' returned non-zero exit status 1.
# Erro na execução da simulação 178: Command '['python', 'XZ.py', '178']' returned non-zero exit status 1.
# Erro na execução da simulação 179: Command '['python', 'XZ.py', '179']' returned non-zero exit status 1.
# Erro na execução da simulação 180: Command '['python', 'XZ.py', '180']' returned non-zero exit status 1.
# Erro na execução da simulação 181: Command '['python', 'XZ.py', '181']' returned non-zero exit status 1.
# Tentativa 182
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 182,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8036827722832874,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 183
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 183,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7860886074830367,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 184: Command '['python', 'XZ.py', '184']' returned non-zero exit status 1.
# Erro na execução da simulação 185: Command '['python', 'XZ.py', '185']' returned non-zero exit status 1.
# Erro na execução da simulação 186: Command '['python', 'XZ.py', '186']' returned non-zero exit status 1.
# Erro na execução da simulação 187: Command '['python', 'XZ.py', '187']' returned non-zero exit status 1.
# Erro na execução da simulação 188: Command '['python', 'XZ.py', '188']' returned non-zero exit status 1.
# Tentativa 189
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 189,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8347034438596092,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 190
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 190,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8231432977217135,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 191: Command '['python', 'XZ.py', '191']' returned non-zero exit status 1.
# Erro na execução da simulação 192: Command '['python', 'XZ.py', '192']' returned non-zero exit status 1.
# Erro na execução da simulação 193: Command '['python', 'XZ.py', '193']' returned non-zero exit status 1.
# Erro na execução da simulação 194: Command '['python', 'XZ.py', '194']' returned non-zero exit status 1.
# Erro na execução da simulação 195: Command '['python', 'XZ.py', '195']' returned non-zero exit status 1.
# Erro na execução da simulação 196: Command '['python', 'XZ.py', '196']' returned non-zero exit status 1.
# Erro na execução da simulação 197: Command '['python', 'XZ.py', '197']' returned non-zero exit status 1.
# Erro na execução da simulação 198: Command '['python', 'XZ.py', '198']' returned non-zero exit status 1.
# Erro na execução da simulação 199: Command '['python', 'XZ.py', '199']' returned non-zero exit status 1.
# Tentativa 200
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 200,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7535862555422662,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 201
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 201,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7618020873432514,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 202: Command '['python', 'XZ.py', '202']' returned non-zero exit status 1.
# Erro na execução da simulação 203: Command '['python', 'XZ.py', '203']' returned non-zero exit status 1.
# Erro na execução da simulação 204: Command '['python', 'XZ.py', '204']' returned non-zero exit status 1.
# Tentativa 205
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 205,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7999299732165365,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 206: Command '['python', 'XZ.py', '206']' returned non-zero exit status 1.
# Tentativa 207
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 207,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7507138886888549,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 208: Command '['python', 'XZ.py', '208']' returned non-zero exit status 1.
# Erro na execução da simulação 209: Command '['python', 'XZ.py', '209']' returned non-zero exit status 1.
# Tentativa 210
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 210,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7935647537699706,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 211: Command '['python', 'XZ.py', '211']' returned non-zero exit status 1.
# Tentativa 212
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 212,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7910447592454309,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 213: Command '['python', 'XZ.py', '213']' returned non-zero exit status 1.
# Erro na execução da simulação 214: Command '['python', 'XZ.py', '214']' returned non-zero exit status 1.
# Erro na execução da simulação 215: Command '['python', 'XZ.py', '215']' returned non-zero exit status 1.
# Tentativa 216
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 216,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7595975144527863,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 217
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 217,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7897917166883615,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 218: Command '['python', 'XZ.py', '218']' returned non-zero exit status 1.
# Erro na execução da simulação 219: Command '['python', 'XZ.py', '219']' returned non-zero exit status 1.
# Erro na execução da simulação 220: Command '['python', 'XZ.py', '220']' returned non-zero exit status 1.
# Erro na execução da simulação 221: Command '['python', 'XZ.py', '221']' returned non-zero exit status 1.
# Erro na execução da simulação 222: Command '['python', 'XZ.py', '222']' returned non-zero exit status 1.
# Tentativa 223
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 223,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.784234624998387,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 224: Command '['python', 'XZ.py', '224']' returned non-zero exit status 1.
# Erro na execução da simulação 225: Command '['python', 'XZ.py', '225']' returned non-zero exit status 1.
# Erro na execução da simulação 226: Command '['python', 'XZ.py', '226']' returned non-zero exit status 1.
# Erro na execução da simulação 227: Command '['python', 'XZ.py', '227']' returned non-zero exit status 1.
# Erro na execução da simulação 228: Command '['python', 'XZ.py', '228']' returned non-zero exit status 1.
# Tentativa 229
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 229,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.799706195702805,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 230: Command '['python', 'XZ.py', '230']' returned non-zero exit status 1.
# Tentativa 231
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 231,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.815137616096699,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 232: Command '['python', 'XZ.py', '232']' returned non-zero exit status 1.
# Erro na execução da simulação 233: Command '['python', 'XZ.py', '233']' returned non-zero exit status 1.
# Erro na execução da simulação 234: Command '['python', 'XZ.py', '234']' returned non-zero exit status 1.
# Tentativa 235
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 235,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7601722119635729,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 236
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 236,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8325367603333353,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 237: Command '['python', 'XZ.py', '237']' returned non-zero exit status 1.
# Erro na execução da simulação 238: Command '['python', 'XZ.py', '238']' returned non-zero exit status 1.
# Erro na execução da simulação 239: Command '['python', 'XZ.py', '239']' returned non-zero exit status 1.
# Erro na execução da simulação 240: Command '['python', 'XZ.py', '240']' returned non-zero exit status 1.
# Erro na execução da simulação 241: Command '['python', 'XZ.py', '241']' returned non-zero exit status 1.
# Erro na execução da simulação 242: Command '['python', 'XZ.py', '242']' returned non-zero exit status 1.
# Erro na execução da simulação 243: Command '['python', 'XZ.py', '243']' returned non-zero exit status 1.
# Erro na execução da simulação 244: Command '['python', 'XZ.py', '244']' returned non-zero exit status 1.
# Erro na execução da simulação 245: Command '['python', 'XZ.py', '245']' returned non-zero exit status 1.
# Tentativa 246
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 246,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8776167533316408,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 247: Command '['python', 'XZ.py', '247']' returned non-zero exit status 1.
# Erro na execução da simulação 248: Command '['python', 'XZ.py', '248']' returned non-zero exit status 1.
# Erro na execução da simulação 249: Command '['python', 'XZ.py', '249']' returned non-zero exit status 1.
# Tentativa 250
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 250,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8331866546818159,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 251: Command '['python', 'XZ.py', '251']' returned non-zero exit status 1.
# Tentativa 252
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 252,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8277096118914506,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 253
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 253,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8531558119245133,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 254: Command '['python', 'XZ.py', '254']' returned non-zero exit status 1.
# Erro na execução da simulação 255: Command '['python', 'XZ.py', '255']' returned non-zero exit status 1.
# Erro na execução da simulação 256: Command '['python', 'XZ.py', '256']' returned non-zero exit status 1.
# Erro na execução da simulação 257: Command '['python', 'XZ.py', '257']' returned non-zero exit status 1.
# Erro na execução da simulação 258: Command '['python', 'XZ.py', '258']' returned non-zero exit status 1.
# Erro na execução da simulação 259: Command '['python', 'XZ.py', '259']' returned non-zero exit status 1.
# Erro na execução da simulação 260: Command '['python', 'XZ.py', '260']' returned non-zero exit status 1.
# Erro na execução da simulação 261: Command '['python', 'XZ.py', '261']' returned non-zero exit status 1.
# Tentativa 262
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 262,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8716948564579783,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 263: Command '['python', 'XZ.py', '263']' returned non-zero exit status 1.
# Erro na execução da simulação 264: Command '['python', 'XZ.py', '264']' returned non-zero exit status 1.
# Tentativa 265
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 265,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.811880729639343,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Tentativa 266
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 266,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8421144589503489,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 267: Command '['python', 'XZ.py', '267']' returned non-zero exit status 1.
# Tentativa 268
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 268,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.814074721694279,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 269: Command '['python', 'XZ.py', '269']' returned non-zero exit status 1.
# Erro na execução da simulação 270: Command '['python', 'XZ.py', '270']' returned non-zero exit status 1.
# Erro na execução da simulação 271: Command '['python', 'XZ.py', '271']' returned non-zero exit status 1.
# Erro na execução da simulação 272: Command '['python', 'XZ.py', '272']' returned non-zero exit status 1.
# Erro na execução da simulação 273: Command '['python', 'XZ.py', '273']' returned non-zero exit status 1.
# Erro na execução da simulação 274: Command '['python', 'XZ.py', '274']' returned non-zero exit status 1.
# Erro na execução da simulação 275: Command '['python', 'XZ.py', '275']' returned non-zero exit status 1.
# Tentativa 276
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 276,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7852928691708423,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 277
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 277,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7977505348838096,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 278: Command '['python', 'XZ.py', '278']' returned non-zero exit status 1.
# Tentativa 279
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 279,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.750965218559162,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 280: Command '['python', 'XZ.py', '280']' returned non-zero exit status 1.
# Erro na execução da simulação 281: Command '['python', 'XZ.py', '281']' returned non-zero exit status 1.
# Erro na execução da simulação 282: Command '['python', 'XZ.py', '282']' returned non-zero exit status 1.
# Erro na execução da simulação 283: Command '['python', 'XZ.py', '283']' returned non-zero exit status 1.
# Erro na execução da simulação 284: Command '['python', 'XZ.py', '284']' returned non-zero exit status 1.
# Erro na execução da simulação 285: Command '['python', 'XZ.py', '285']' returned non-zero exit status 1.
# Erro na execução da simulação 286: Command '['python', 'XZ.py', '286']' returned non-zero exit status 1.
# Erro na execução da simulação 287: Command '['python', 'XZ.py', '287']' returned non-zero exit status 1.
# Erro na execução da simulação 288: Command '['python', 'XZ.py', '288']' returned non-zero exit status 1.
# Erro na execução da simulação 289: Command '['python', 'XZ.py', '289']' returned non-zero exit status 1.
# Erro na execução da simulação 290: Command '['python', 'XZ.py', '290']' returned non-zero exit status 1.
# Erro na execução da simulação 291: Command '['python', 'XZ.py', '291']' returned non-zero exit status 1.
# Erro na execução da simulação 292: Command '['python', 'XZ.py', '292']' returned non-zero exit status 1.
# Erro na execução da simulação 293: Command '['python', 'XZ.py', '293']' returned non-zero exit status 1.
# Erro na execução da simulação 294: Command '['python', 'XZ.py', '294']' returned non-zero exit status 1.
# Erro na execução da simulação 295: Command '['python', 'XZ.py', '295']' returned non-zero exit status 1.
# Erro na execução da simulação 296: Command '['python', 'XZ.py', '296']' returned non-zero exit status 1.
# Erro na execução da simulação 297: Command '['python', 'XZ.py', '297']' returned non-zero exit status 1.
# Erro na execução da simulação 298: Command '['python', 'XZ.py', '298']' returned non-zero exit status 1.
# Erro na execução da simulação 299: Command '['python', 'XZ.py', '299']' returned non-zero exit status 1.
# Erro na execução da simulação 300: Command '['python', 'XZ.py', '300']' returned non-zero exit status 1.
# Erro na execução da simulação 301: Command '['python', 'XZ.py', '301']' returned non-zero exit status 1.
# Erro na execução da simulação 302: Command '['python', 'XZ.py', '302']' returned non-zero exit status 1.
# Tentativa 303
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 303,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8129570931673582,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 304: Command '['python', 'XZ.py', '304']' returned non-zero exit status 1.
# Erro na execução da simulação 305: Command '['python', 'XZ.py', '305']' returned non-zero exit status 1.
# Tentativa 306
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 306,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8117257214189493,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 307: Command '['python', 'XZ.py', '307']' returned non-zero exit status 1.
# Erro na execução da simulação 308: Command '['python', 'XZ.py', '308']' returned non-zero exit status 1.
# Erro na execução da simulação 309: Command '['python', 'XZ.py', '309']' returned non-zero exit status 1.
# Erro na execução da simulação 310: Command '['python', 'XZ.py', '310']' returned non-zero exit status 1.
# Erro na execução da simulação 311: Command '['python', 'XZ.py', '311']' returned non-zero exit status 1.
# Tentativa 312
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 312,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.77850781266697,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 313: Command '['python', 'XZ.py', '313']' returned non-zero exit status 1.
# Tentativa 314
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 314,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8243404703613676,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 315
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 315,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7967522421767207,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 316: Command '['python', 'XZ.py', '316']' returned non-zero exit status 1.
# Erro na execução da simulação 317: Command '['python', 'XZ.py', '317']' returned non-zero exit status 1.
# Erro na execução da simulação 318: Command '['python', 'XZ.py', '318']' returned non-zero exit status 1.
# Erro na execução da simulação 319: Command '['python', 'XZ.py', '319']' returned non-zero exit status 1.
# Erro na execução da simulação 320: Command '['python', 'XZ.py', '320']' returned non-zero exit status 1.
# Tentativa 321
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 321,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7835608963388089,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 322: Command '['python', 'XZ.py', '322']' returned non-zero exit status 1.
# Erro na execução da simulação 323: Command '['python', 'XZ.py', '323']' returned non-zero exit status 1.
# Erro na execução da simulação 324: Command '['python', 'XZ.py', '324']' returned non-zero exit status 1.
# Erro na execução da simulação 325: Command '['python', 'XZ.py', '325']' returned non-zero exit status 1.
# Erro na execução da simulação 326: Command '['python', 'XZ.py', '326']' returned non-zero exit status 1.
# Erro na execução da simulação 327: Command '['python', 'XZ.py', '327']' returned non-zero exit status 1.
# Erro na execução da simulação 328: Command '['python', 'XZ.py', '328']' returned non-zero exit status 1.
# Erro na execução da simulação 329: Command '['python', 'XZ.py', '329']' returned non-zero exit status 1.
# Tentativa 330
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 330,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8065115744528849,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 331
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 331,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7627861771448051,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 332: Command '['python', 'XZ.py', '332']' returned non-zero exit status 1.
# Erro na execução da simulação 333: Command '['python', 'XZ.py', '333']' returned non-zero exit status 1.
# Erro na execução da simulação 334: Command '['python', 'XZ.py', '334']' returned non-zero exit status 1.
# Erro na execução da simulação 335: Command '['python', 'XZ.py', '335']' returned non-zero exit status 1.
# Tentativa 336
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 336,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8593933289801915,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 337: Command '['python', 'XZ.py', '337']' returned non-zero exit status 1.
# Erro na execução da simulação 338: Command '['python', 'XZ.py', '338']' returned non-zero exit status 1.
# Erro na execução da simulação 339: Command '['python', 'XZ.py', '339']' returned non-zero exit status 1.
# Erro na execução da simulação 340: Command '['python', 'XZ.py', '340']' returned non-zero exit status 1.
# Erro na execução da simulação 341: Command '['python', 'XZ.py', '341']' returned non-zero exit status 1.
# Erro na execução da simulação 342: Command '['python', 'XZ.py', '342']' returned non-zero exit status 1.
# Erro na execução da simulação 343: Command '['python', 'XZ.py', '343']' returned non-zero exit status 1.
# Tentativa 344
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 344,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8043995145828196,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 345: Command '['python', 'XZ.py', '345']' returned non-zero exit status 1.
# Tentativa 346
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 346,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8171639167236806,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 347: Command '['python', 'XZ.py', '347']' returned non-zero exit status 1.
# Erro na execução da simulação 348: Command '['python', 'XZ.py', '348']' returned non-zero exit status 1.
# Erro na execução da simulação 349: Command '['python', 'XZ.py', '349']' returned non-zero exit status 1.
# Tentativa 350
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 350,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7710588454065879,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 351: Command '['python', 'XZ.py', '351']' returned non-zero exit status 1.
# Tentativa 352
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 352,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7710698461404788,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 353: Command '['python', 'XZ.py', '353']' returned non-zero exit status 1.
# Erro na execução da simulação 354: Command '['python', 'XZ.py', '354']' returned non-zero exit status 1.
# Erro na execução da simulação 355: Command '['python', 'XZ.py', '355']' returned non-zero exit status 1.
# Erro na execução da simulação 356: Command '['python', 'XZ.py', '356']' returned non-zero exit status 1.
# Erro na execução da simulação 357: Command '['python', 'XZ.py', '357']' returned non-zero exit status 1.
# Erro na execução da simulação 358: Command '['python', 'XZ.py', '358']' returned non-zero exit status 1.
# Erro na execução da simulação 359: Command '['python', 'XZ.py', '359']' returned non-zero exit status 1.
# Tentativa 360
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 360,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8513150893066574,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Erro na execução da simulação 361: Command '['python', 'XZ.py', '361']' returned non-zero exit status 1.
# Erro na execução da simulação 362: Command '['python', 'XZ.py', '362']' returned non-zero exit status 1.
# Erro na execução da simulação 363: Command '['python', 'XZ.py', '363']' returned non-zero exit status 1.
# Erro na execução da simulação 364: Command '['python', 'XZ.py', '364']' returned non-zero exit status 1.
# Erro na execução da simulação 365: Command '['python', 'XZ.py', '365']' returned non-zero exit status 1.
# Erro na execução da simulação 366: Command '['python', 'XZ.py', '366']' returned non-zero exit status 1.
# Erro na execução da simulação 367: Command '['python', 'XZ.py', '367']' returned non-zero exit status 1.
# Tentativa 368
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 368,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7636267985449308,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 369
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 369,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.828329756013397,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7535694915975797
# }
# Erro na execução da simulação 370: Command '['python', 'XZ.py', '370']' returned non-zero exit status 1.
# Tentativa 371
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 371,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7540942694541103,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 372: Command '['python', 'XZ.py', '372']' returned non-zero exit status 1.
# Tentativa 373
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 373,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8685035863893996,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 374
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 374,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8621991279535556,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 375
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 375,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7968386701012419,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 376: Command '['python', 'XZ.py', '376']' returned non-zero exit status 1.
# Erro na execução da simulação 377: Command '['python', 'XZ.py', '377']' returned non-zero exit status 1.
# Erro na execução da simulação 378: Command '['python', 'XZ.py', '378']' returned non-zero exit status 1.
# Erro na execução da simulação 379: Command '['python', 'XZ.py', '379']' returned non-zero exit status 1.
# Erro na execução da simulação 380: Command '['python', 'XZ.py', '380']' returned non-zero exit status 1.
# Erro na execução da simulação 381: Command '['python', 'XZ.py', '381']' returned non-zero exit status 1.
# Erro na execução da simulação 382: Command '['python', 'XZ.py', '382']' returned non-zero exit status 1.
# Tentativa 383
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 383,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8790245106398911,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Erro na execução da simulação 384: Command '['python', 'XZ.py', '384']' returned non-zero exit status 1.
# Erro na execução da simulação 385: Command '['python', 'XZ.py', '385']' returned non-zero exit status 1.
# Tentativa 386
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 386,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7943481211525169,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Erro na execução da simulação 387: Command '['python', 'XZ.py', '387']' returned non-zero exit status 1.
# Tentativa 388
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 388,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8118917354266945,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 389: Command '['python', 'XZ.py', '389']' returned non-zero exit status 1.
# Erro na execução da simulação 390: Command '['python', 'XZ.py', '390']' returned non-zero exit status 1.
# Erro na execução da simulação 391: Command '['python', 'XZ.py', '391']' returned non-zero exit status 1.
# Erro na execução da simulação 392: Command '['python', 'XZ.py', '392']' returned non-zero exit status 1.
# Erro na execução da simulação 393: Command '['python', 'XZ.py', '393']' returned non-zero exit status 1.
# Erro na execução da simulação 394: Command '['python', 'XZ.py', '394']' returned non-zero exit status 1.
# Erro na execução da simulação 395: Command '['python', 'XZ.py', '395']' returned non-zero exit status 1.
# Erro na execução da simulação 396: Command '['python', 'XZ.py', '396']' returned non-zero exit status 1.
# Erro na execução da simulação 397: Command '['python', 'XZ.py', '397']' returned non-zero exit status 1.
# Erro na execução da simulação 398: Command '['python', 'XZ.py', '398']' returned non-zero exit status 1.
# Erro na execução da simulação 399: Command '['python', 'XZ.py', '399']' returned non-zero exit status 1.
# Erro na execução da simulação 400: Command '['python', 'XZ.py', '400']' returned non-zero exit status 1.
# Erro na execução da simulação 401: Command '['python', 'XZ.py', '401']' returned non-zero exit status 1.
# Erro na execução da simulação 402: Command '['python', 'XZ.py', '402']' returned non-zero exit status 1.
# Tentativa 403
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 403,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7619477955847209,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Erro na execução da simulação 404: Command '['python', 'XZ.py', '404']' returned non-zero exit status 1.
# Erro na execução da simulação 405: Command '['python', 'XZ.py', '405']' returned non-zero exit status 1.
# Erro na execução da simulação 406: Command '['python', 'XZ.py', '406']' returned non-zero exit status 1.
# Erro na execução da simulação 407: Command '['python', 'XZ.py', '407']' returned non-zero exit status 1.
# Erro na execução da simulação 408: Command '['python', 'XZ.py', '408']' returned non-zero exit status 1.
# Tentativa 409
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 409,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7870253411370529,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7563392882959928
# }
# Erro na execução da simulação 410: Command '['python', 'XZ.py', '410']' returned non-zero exit status 1.
#
# Resumo das Métricas da Simulação (após todas as tentativas):
# Total de Timeslots: 171
# Total de EPRs Criados: 0
# Total de EPRs Consumidos: 496
# Fidelidade Média Total: 0.741153043621279
