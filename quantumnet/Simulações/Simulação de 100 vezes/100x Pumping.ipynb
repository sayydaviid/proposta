# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(100):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "100x.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8500940293640384,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 2
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9346277477795467,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 3
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9183348471963947,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 4
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9238052781498047,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 5
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 5,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9354319577256287,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 6
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9216520788080544,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 7
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 7,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8649087386019161,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 8
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7949282129437493,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 9
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8365100248678586,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 10
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8669532799073543,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7761947613234712,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 12
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8789363849440537,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8030572800751472,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 14
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 14,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.839801331528984,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 15
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 15,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7907157624295944,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 16
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8817519913282906,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 17
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.762044562928502,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 18
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9173521217669026,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 19
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8512878883861393,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 20
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8399417604477712,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 21
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7636960668950837,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8169625399711162,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 23
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7561519699850789,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 24
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7522841412251456,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 25
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8695508993132532,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.6792092999999999
# }
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8279294090485829,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 27
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 27,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8328842376012775,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9590951581438962,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 29
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8767015634379062,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8977528206893014,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 31
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7791855018686067,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 32
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 32,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9488942877499842,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 33
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 33,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8775683935816428,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 34
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8446055622796745,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 35
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7639404068046824,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 36
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9538807123512129,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 37
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8391562111485145,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 38
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9074874172938998,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 39
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.797730920179383,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 40
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 40,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9418551533441621,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 41
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7810561086815437,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8147744885158518,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8255293893949471,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 44
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7758904679696655,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 45
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9480281119416285,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 46
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9384925507794437,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 47
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8416635198531872,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 48
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9311565202502802,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 49
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 49,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9010800959496273,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.68607
# }
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9340527989855207,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 51
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9263213225086346,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 52
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8377304610347985,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 53
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9488463543584716,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 54
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8761561537427071,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 55
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 55,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7732555795667775,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 56
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 56,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9503198587121497,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 57
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9452909233270282,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 58
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7572440361469178,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 59
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 59,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8260164181164119,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 60
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9334928683945471,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7802723662702905,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9433418546047403,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.693
# }
# Tentativa 63
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 63,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9207568385380948,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 64
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8691266358580064,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 65
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8227991438598445,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 66
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9308326506698147,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 67
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.750936374269958,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 68
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8853368039074305,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 69
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 69,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.7506223109211367,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7542372881355933
# }
# Tentativa 70
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8429850992859655,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 71
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8029778475861713,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 72
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 72,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9349471315662675,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 73
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.814443783162161,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 74
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9250432240335182,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9552720937920065,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 76
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.869814000832429,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 77
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9193928244850065,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 78
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8736975848417514,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 79
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9098748680430112,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 80
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9376792256729124,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 81
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9452933641896202,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 82
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7659216770967016,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 83
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9146672081152221,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 84
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8751296050009635,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 85
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8851255806233037,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 86
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.8073052732840192,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 87
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9063826157456479,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 88
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8549720150089413,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 89
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 89,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8811094153217323,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8805404332849779,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 91
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 91,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8203812060433838,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7500515533721627,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 93
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8898066038561535,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 94
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9225061546050249,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 95
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 95,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9086556925061082,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7989588120947753,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 97
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9174345541715858,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 98
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8543488633578709,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.927027027027027
# }
# Tentativa 99
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 99,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8896865540311314,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 100
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7970383442222421,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
#
# Resumo das Métricas da Simulação (após todas as tentativas):
# Total de Timeslots: 78
# Total de EPRs Criados: 0
# Total de EPRs Consumidos: 286
# Fidelidade Média Total: 0.8279611258348057
