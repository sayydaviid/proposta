# %%
import subprocess
import csv
import json

# Inicializa acumuladores para o resumo
total_timeslots = 0
total_eprs_created = 0
total_eprs_consumed = 0
total_fidelity = 0.0
fidelity_count = 0

# Caminho do arquivo CSV
csv_file_path = "link_metrics_output.csv"

# Loop para rodar a simulação 10 vezes
for attempt in range(100):
    try:
        # Executa o script simulation.py em um novo processo, passando o índice da simulação como argumento
        result = subprocess.run(
            ["python", "100x.py", str(attempt + 1)],
            capture_output=True,
            text=True,
            check=True
        )

        # Verifica se a saída é JSON válida
        simulation_result = json.loads(result.stdout.strip())
        
    except subprocess.CalledProcessError as e:
        print(f"Erro na execução da simulação {attempt + 1}: {e}")
        continue
    except json.JSONDecodeError:
        print(f"Tentativa {attempt + 1} \n Saída obtida: {result.stdout.strip()}")
        continue

try:
    with open(csv_file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Pula o cabeçalho
        
        for row in reader:
            # Verifica se a linha tem o número esperado de colunas
            if len(row) < 6:
                print(f"Linha inválida no CSV: {row}")
                continue
            
            try:
                # Processa as métricas corretamente
                timeslot_total = int(row[2])
                eprs_created = int(row[3])
                eprs_consumed = int(row[4])
                fidelity_avg_raw = row[5]

                # Deserializa a fidelidade média
                fidelity_avg = 0.0
                try:
                    fidelity_avg = json.loads(fidelity_avg_raw.replace("'", "\""))
                    if isinstance(fidelity_avg, dict) and 'media' in fidelity_avg:
                        fidelity_avg = fidelity_avg['media']
                    else:
                        fidelity_avg = 0.0
                except json.JSONDecodeError:
                    fidelity_avg = 0.0

                # Atualiza as métricas acumuladas
                total_timeslots += timeslot_total
                total_eprs_created += eprs_created
                total_eprs_consumed += eprs_consumed
                if isinstance(fidelity_avg, (int, float)) and fidelity_avg > 0:
                    total_fidelity += fidelity_avg
                    fidelity_count += 1
            except (IndexError, ValueError) as e:
                print(f"Erro ao processar a linha: {row}. Erro: {e}")
                continue

except FileNotFoundError:
    print(f"Arquivo {csv_file_path} não encontrado.")
except Exception as e:
    print(f"Erro ao processar o arquivo CSV: {e}")

# Calcula a fidelidade média total
average_fidelity = total_fidelity / fidelity_count if fidelity_count > 0 else 0.0

# Exibe o resumo das métricas no final
print("\nResumo das Métricas da Simulação (após todas as tentativas):")
print(f"Total de Timeslots: {total_timeslots}")
print(f"Total de EPRs Criados: {total_eprs_created}")
print(f"Total de EPRs Consumidos: {total_eprs_consumed}")
print(f"Fidelidade Média Total: {average_fidelity}")
# Out:
# Tentativa 1
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 1,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7944620618559842,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 2
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 2,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8646117222220984,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 3
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 3,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8709148786743555,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 4
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 4,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7663417656405652,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 5
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 5,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.894632264870968,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 6
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 6,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8261772120942897,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 7
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 7,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8250784614765145,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 8
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 8,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8983218974908532,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 9
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 9,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9039157959241714,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 10
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 10,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8157090732529314,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 11
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 11,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7775617887370838,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 12
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 12,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9180888769627036,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 13
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 13,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9057558060550579,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 14
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 14,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9264644732883156,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 15
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 15,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8980603291656011,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 16
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 16,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8840552622623885,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 17
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 17,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8338409730732399,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 18
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 18,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9544371829879235,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 19
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 19,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9215388959457366,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 20
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 20,
#     "success": false,
#     "estimated_rounds": 7,
#     "request": 0.9247506360592402,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 21
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 21,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8218198619372326,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 22
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 22,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.907609031426984,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 23
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 23,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8056372652543109,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 24
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 24,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7680455524553064,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 25
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 25,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9287304618278824,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 26
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 26,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7642201596953074,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 27
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 27,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8334775852525173,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 28
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 28,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8473997841096258,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 29
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 29,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8488744060305438,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 30
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 30,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8209325737901297,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 31
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 31,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8280090142997744,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 32
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 32,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7995012997762588,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 33
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 33,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8367895243824814,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 34
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 34,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8541513611196325,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 35
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 35,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8866133596675154,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 36
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 36,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.878249079144937,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 37
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 37,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8644304179808793,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 38
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 38,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8193281016562535,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 39
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 39,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8910890408433041,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 40
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 40,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.8886775289522497,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 41
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 41,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8775597072088073,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 42
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 42,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9114930166470343,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 43
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 43,
#     "success": false,
#     "estimated_rounds": 9,
#     "request": 0.9573193224797716,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 44
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 44,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8562351988628917,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 45
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 45,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7957701021466166,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 46
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 46,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7806955171920741,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 47
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 47,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9194373589606104,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 48
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 48,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9547169695626593,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 49
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 49,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8757677670443382,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 50
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 50,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9039546371680173,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 51
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 51,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8853733431377746,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 52
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 52,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7787257332832601,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 53
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 53,
#     "success": false,
#     "estimated_rounds": 5,
#     "request": 0.8515993967324599,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 54
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 54,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8919190781157914,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 55
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 55,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7505312665033871,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 56
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 56,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7775091273489483,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 57
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 57,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.859250293594014,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 58
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 58,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9300167539997701,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 59
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 59,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7658410101698833,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 60
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 60,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7506151811023527,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 61
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 61,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.9041892606049863,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 62
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 62,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8184877336821916,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 63
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 63,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9005999317217773,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 64
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 64,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.7718447268747497,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 65
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 65,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.833621653590868,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 66
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 66,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8205546342418684,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 67
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 67,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9085843547211697,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 68
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 68,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9025294460577501,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 69
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 69,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8074153978783438,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 70
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 70,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9563852707473937,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 71
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 71,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.7652963174390432,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 72
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 72,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8640361424577809,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 73
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 73,
#     "success": false,
#     "estimated_rounds": 4,
#     "request": 0.8342322354851809,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 74
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 74,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7769946831156377,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 75
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 75,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9536371378634774,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 76
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 76,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9540363343351623,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 77
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 77,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9212376183578391,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 78
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 78,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8011324996210645,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 79
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 79,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.7979407450055701,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 80
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 80,
#     "success": false,
#     "estimated_rounds": 8,
#     "request": 0.9548729034945811,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 81
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 81,
#     "success": true,
#     "estimated_rounds": 2,
#     "request": 0.8571216949962221,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.967365028203062
# }
# Tentativa 82
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 82,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9411955090446436,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 83
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 83,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.751785556615127,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 84
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 84,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.923235020591771,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 85
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 85,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.777481651688222,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 86
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 86,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8080890481358135,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 87
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 87,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.758383132231774,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 88
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 88,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9350245246469457,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 89
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 89,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9290860751888861,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 90
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 90,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8371525350856833,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 91
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 91,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7865036605139032,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7352941176470588
# }
# Tentativa 92
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 92,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9020537309888866,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 93
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 93,
#     "success": false,
#     "estimated_rounds": 1,
#     "request": 0.8009878004275062,
#     "channel_info": "X",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 94
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 94,
#     "success": true,
#     "estimated_rounds": 1,
#     "request": 0.8290122000668718,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.8448275862068965
# }
# Tentativa 95
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 95,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9574631042429601,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 96
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 96,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9402637389949916,
#     "channel_info": "Y",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 97
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 97,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.9239616269588059,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 98
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 98,
#     "success": false,
#     "estimated_rounds": 3,
#     "request": 0.7775334012662496,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 99
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 99,
#     "success": false,
#     "estimated_rounds": 2,
#     "request": 0.8493303299445767,
#     "channel_info": "Z",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
# Tentativa 100
#  Saída obtida: Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados
# {
#     "simulation": 100,
#     "success": false,
#     "estimated_rounds": 6,
#     "request": 0.9092340326750548,
#     "channel_info": "XZ",
#     "initial_fidelity": 0.7,
#     "final_fidelity": 0.7
# }
#
# Resumo das Métricas da Simulação (após todas as tentativas):
# Total de Timeslots: 46
# Total de EPRs Criados: 1316
# Total de EPRs Consumidos: 354
# Fidelidade Média Total: 0.82806055818643
