# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology("Grade", 3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: [<quantumnet.objects.qubit.Qubit object at 0x000001D0D9076910>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076950>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076990>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D90769D0>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076A10>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076A90>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076AD0>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076B10>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076B50>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9076A50>]
# memoria de bob: [<quantumnet.objects.qubit.Qubit object at 0x000001D0D9080850>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D90808D0>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080950>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D90809D0>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080A50>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080B10>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080B90>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080C10>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080C90>, <quantumnet.objects.qubit.Qubit object at 0x000001D0D9080CD0>]

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
rede.transportlayer.run_transport_layer(0,8,11)
# Out:
# 2024-09-17 00:44:24,179: Número insuficiente de qubits na memória de Alice (Host 0). Criando mais 1 qubits para completar os 11 necessários.
# 2024-09-17 00:44:24,180: Timeslot antes da criação do qubit: 1
# 2024-09-17 00:44:24,182: Qubit 90 adicionado à memória do Host 0.
# 2024-09-17 00:44:24,183: Qubit 90 criado com fidelidade inicial 0.7620490470903759 e adicionado à memória do Host 0.
# 2024-09-17 00:44:24,184: Qubit criado para Alice (Host 0) no timeslot: 2
# 2024-09-17 00:44:24,185: Tentativa 1 de transmissão de qubits entre 0 e 8.
# 2024-09-17 00:44:24,185: Timeslot 3: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,188: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,189: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.2363687492145497.
# 2024-09-17 00:44:24,190: Timeslot 4: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,191: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,192: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.3671543825919449.
# 2024-09-17 00:44:24,193: Timeslot 5: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,194: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,195: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.01887270001414548.
# 2024-09-17 00:44:24,197: Timeslot 6: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,198: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,199: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.022769993875717015.
# 2024-09-17 00:44:24,200: Timeslot 7: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,201: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,201: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.028604161990649753.
# 2024-09-17 00:44:24,202: Timeslot 8: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,203: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,204: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.07328641964481597.
# 2024-09-17 00:44:24,204: Timeslot 9: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,205: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,206: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.13541722476705548.
# 2024-09-17 00:44:24,206: Timeslot 10: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,207: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,207: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.039725430982378566.
# 2024-09-17 00:44:24,208: Timeslot 11: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,208: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,209: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.017002676473893048.
# 2024-09-17 00:44:24,209: Timeslot 12: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,212: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,214: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.010750088606970633.
# 2024-09-17 00:44:24,214: Timeslot 13: Buscando rota válida entre 0 e 8.
# 2024-09-17 00:44:24,215: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-09-17 00:44:24,216: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.060785941936519455.
# 2024-09-17 00:44:24,217: Transmissão e teletransporte de 11 qubits entre 0 e 8 concluídos com sucesso. Timeslot: 13
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-09-17 00:44:24,236: Qubits usados na camada PhysicalLayer: 1
# 2024-09-17 00:44:24,237: Qubits usados na camada LinkLayer: 0
# 2024-09-17 00:44:24,237: Qubits usados na camada TransportLayer: 11
# 2024-09-17 00:44:24,238: Qubits usados na camada ApplicationLayer: 0
# 12

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.3242369673724964,
#   'fidelity_route': 0.7289999999999994,
#   'F_final': 0.2363687492145497,
#   'timeslot': 3,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076910>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.5596012537600138,
#   'fidelity_route': 0.6560999999999997,
#   'F_final': 0.3671543825919449,
#   'timeslot': 4,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076950>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.03196108319217172,
#   'fidelity_route': 0.5904900000000001,
#   'F_final': 0.01887270001414548,
#   'timeslot': 5,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076990>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.04284576063140968,
#   'fidelity_route': 0.5314410000000006,
#   'F_final': 0.022769993875717015,
#   'timeslot': 6,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d90769d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.05980419691336018,
#   'fidelity_route': 0.47829690000000014,
#   'F_final': 0.028604161990649753,
#   'timeslot': 7,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076a10>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.17024855306590247,
#   'fidelity_route': 0.4304672099999999,
#   'F_final': 0.07328641964481597,
#   'timeslot': 8,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076a90>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.34953552693248346,
#   'fidelity_route': 0.38742048900000015,
#   'F_final': 0.13541722476705548,
#   'timeslot': 9,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076ad0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.11393142337961985,
#   'fidelity_route': 0.3486784401000004,
#   'F_final': 0.039725430982378566,
#   'timeslot': 10,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076b10>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.054181333217367525,
#   'fidelity_route': 0.3138105960900005,
#   'F_final': 0.017002676473893048,
#   'timeslot': 11,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076b50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.03806290496707243,
#   'fidelity_route': 0.2824295364810004,
#   'F_final': 0.010750088606970633,
#   'timeslot': 12,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0d9076a50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.23913906571724736,
#   'fidelity_route': 0.2541865828329002,
#   'F_final': 0.060785941936519455,
#   'timeslot': 13,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d0e945ed90>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-09-17 00:44:24,295: Fidelidade do qubit utilizado de 0 para 8: 0.2363687492145497
# 2024-09-17 00:44:24,296: Fidelidade do qubit utilizado de 0 para 8: 0.3671543825919449
# 2024-09-17 00:44:24,297: Fidelidade do qubit utilizado de 0 para 8: 0.01887270001414548
# 2024-09-17 00:44:24,298: Fidelidade do qubit utilizado de 0 para 8: 0.022769993875717015
# 2024-09-17 00:44:24,298: Fidelidade do qubit utilizado de 0 para 8: 0.028604161990649753
# 2024-09-17 00:44:24,299: Fidelidade do qubit utilizado de 0 para 8: 0.07328641964481597
# 2024-09-17 00:44:24,299: Fidelidade do qubit utilizado de 0 para 8: 0.13541722476705548
# 2024-09-17 00:44:24,300: Fidelidade do qubit utilizado de 0 para 8: 0.039725430982378566
# 2024-09-17 00:44:24,301: Fidelidade do qubit utilizado de 0 para 8: 0.017002676473893048
# 2024-09-17 00:44:24,301: Fidelidade do qubit utilizado de 0 para 8: 0.010750088606970633
# 2024-09-17 00:44:24,302: Fidelidade do qubit utilizado de 0 para 8: 0.060785941936519455
# 2024-09-17 00:44:24,303: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.09188525182714909
# 0.09188525182714909

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 13

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0
# Qubit 1 foi criado no timeslot 0
# Qubit 2 foi criado no timeslot 0
# Qubit 3 foi criado no timeslot 0
# Qubit 4 foi criado no timeslot 0
# Qubit 5 foi criado no timeslot 0
# Qubit 6 foi criado no timeslot 0
# Qubit 7 foi criado no timeslot 0
# Qubit 8 foi criado no timeslot 0
# Qubit 9 foi criado no timeslot 0
# Qubit 10 foi criado no timeslot 0
# Qubit 11 foi criado no timeslot 0
# Qubit 12 foi criado no timeslot 0
# Qubit 13 foi criado no timeslot 0
# Qubit 14 foi criado no timeslot 0
# Qubit 15 foi criado no timeslot 0
# Qubit 16 foi criado no timeslot 0
# Qubit 17 foi criado no timeslot 0
# Qubit 18 foi criado no timeslot 0
